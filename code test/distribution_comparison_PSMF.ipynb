# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import ks_2samp, wasserstein_distance

def hellinger(p, q):
    """Calculate the Hellinger distance between two probability distributions."""
    return np.sqrt(np.sum((np.sqrt(p) - np.sqrt(q))**2)) / np.sqrt(2)

# Load the original dataset
original_path = '/Users/guillermodominguez/Documents/Imperial College London/Dissertation/rPSMF/ExperimentImpute/data/sp500_closing_prices_masked_20percent.csv'
df_original = pd.read_csv(original_path, header=None)

# Load the imputed dataset from PSMF
psmf_path = '/Users/guillermodominguez/Documents/Imperial College London/Dissertation/rPSMF/Y_imputed_20_PSMF.csv'
df_imputed = pd.read_csv(psmf_path, header=None)

# Only replace missing values in the original dataset with values from the imputed dataset
df_final = df_original.copy()
mask = df_original.isna()  # Create a boolean mask for where NaN values are in the original dataframe
df_final[mask] = df_imputed[mask]  # Replace only the NaN values

# Impute missing values with the mean of each row
df_mean_imputed = df_original.copy()

# Apply row-wise mean imputation
for index, row in df_mean_imputed.iterrows():
    # Calculate the mean of the current row excluding NaNs
    row_mean = row.mean()
    # Fill NaNs in this row with the calculated mean
    df_mean_imputed.iloc[index] = row.fillna(row_mean)

# Find rows that contain at least one NaN
rows_with_nan = mask.any(axis=1)

# Get indices of these rows
rows_with_nan_indices = rows_with_nan[rows_with_nan].index.tolist()

# Initialize lists to store results for plotting
ks_stats_psmf = []
ks_pvalues_psmf = []
ks_stats_mean = []
ks_pvalues_mean = []
wasserstein_psmf_list = []
wasserstein_mean_list = []
hellinger_psmf_list = []
hellinger_mean_list = []

for idx, stock_row in enumerate(rows_with_nan_indices, start=1):
    
    # Drop NA values for the original for a fair comparison
    original_clean = df_original.iloc[stock_row].dropna()

    # Normalize the data for Hellinger distance calculation
    original_hist, _ = np.histogram(original_clean, bins=50, density=True)
    psmf_hist, _ = np.histogram(df_final.iloc[stock_row].dropna(), bins=50, density=True)
    mean_hist, _ = np.histogram(df_mean_imputed.iloc[stock_row].dropna(), bins=50, density=True)
    
    # Calculate the Hellinger distance
    hellinger_psmf = hellinger(original_hist, psmf_hist)
    hellinger_mean = hellinger(original_hist, mean_hist)
    
    # Append Hellinger distances to lists
    hellinger_psmf_list.append(hellinger_psmf)
    hellinger_mean_list.append(hellinger_mean)

    # KS Test between original and PSMF imputed
    ks_stat_psmf, ks_pvalue_psmf = ks_2samp(original_clean, df_final.iloc[stock_row].dropna())
    ks_stats_psmf.append(ks_stat_psmf)
    ks_pvalues_psmf.append(ks_pvalue_psmf)

    # KS Test between original and Mean imputed
    ks_stat_mean, ks_pvalue_mean = ks_2samp(original_clean, df_mean_imputed.iloc[stock_row].dropna())
    ks_stats_mean.append(ks_stat_mean)
    ks_pvalues_mean.append(ks_pvalue_mean)

    # Wasserstein Distance between original and PSMF imputed
    wasserstein_psmf = wasserstein_distance(original_clean, df_final.iloc[stock_row].dropna())
    wasserstein_psmf_list.append(wasserstein_psmf)

    # Wasserstein Distance between original and Mean imputed
    wasserstein_mean = wasserstein_distance(original_clean, df_mean_imputed.iloc[stock_row].dropna())
    wasserstein_mean_list.append(wasserstein_mean)
    
    # Plotting individual distributions
    plt.figure(figsize=(18, 6))

    # Original data distribution
    plt.subplot(1, 3, 1)
    df_original.iloc[stock_row].dropna().hist(bins=50, alpha=0.7, label='Original')
    plt.title(f'Original Data Distribution for Stock {idx}')
    plt.legend()

    # Distribution after PSMF imputation
    plt.subplot(1, 3, 2)
    df_final.iloc[stock_row].hist(bins=50, alpha=0.7, color='orange', label='PSMF Imputed')
    plt.title(f'Imputed Data Distribution for Stock {idx}')
    plt.legend()

    # Distribution after mean imputation
    plt.subplot(1, 3, 3)
    df_mean_imputed.iloc[stock_row].hist(bins=50, alpha=0.7, color='green', label='Mean Imputed')
    plt.title(f'Mean Imputed Data Distribution for Stock {idx}')
    plt.legend()

    #plt.show()

    # Print KS, Wasserstein, and Hellinger results for this stock
    print(f"Stock {idx} - KS Statistic PSMF: {ks_stat_psmf}, P-value PSMF: {ks_pvalue_psmf}")
    print(f"Stock {idx} - KS Statistic Mean: {ks_stat_mean}, P-value Mean: {ks_pvalue_mean}")
    print(f"Stock {idx} - Wasserstein Distance PSMF: {wasserstein_psmf}")
    print(f"Stock {idx} - Wasserstein Distance Mean: {wasserstein_mean}")
    print(f"Stock {idx} - Hellinger Distance PSMF: {hellinger_psmf}")
    print(f"Stock {idx} - Hellinger Distance Mean: {hellinger_mean}")
    print("\n" + "="*80 + "\n")

# Calculate means for the Wasserstein distances, KS statistics, and Hellinger distances
mean_wasserstein_psmf = sum(wasserstein_psmf_list) / len(wasserstein_psmf_list)
mean_wasserstein_mean = sum(wasserstein_mean_list) / len(wasserstein_mean_list)

mean_ks_stat_psmf = sum(ks_stats_psmf) / len(ks_stats_psmf)
mean_ks_stat_mean = sum(ks_stats_mean) / len(ks_stats_mean)

mean_hellinger_psmf = sum(hellinger_psmf_list) / len(hellinger_psmf_list)
mean_hellinger_mean = sum(hellinger_mean_list) / len(hellinger_mean_list)

# Plot Wasserstein distances with ordinal stock number and mean lines
plt.figure(figsize=(12, 6))
plt.plot(range(1, len(wasserstein_psmf_list) + 1), wasserstein_psmf_list, label='PSMF Imputed', alpha=0.7, color='orange')
plt.plot(range(1, len(wasserstein_mean_list) + 1), wasserstein_mean_list, label='Mean Imputed', alpha=0.7, color='green')
plt.axhline(mean_wasserstein_psmf, color='orange', linestyle='--', label='Mean PSMF')
plt.axhline(mean_wasserstein_mean, color='green', linestyle='--', label='Mean Imputed')
plt.xlabel('Stock Number (Ordinal)')
plt.ylabel('Wasserstein Distance')
plt.title('Wasserstein Distance Comparison for Mean and PSMF Imputed Data')
plt.legend()
#plt.show()

# Plot KS statistics with ordinal stock number and mean lines
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(range(1, len(ks_stats_psmf) + 1), ks_stats_psmf, label='KS Statistic PSMF', alpha=0.7, color='orange')
plt.plot(range(1, len(ks_stats_mean) + 1), ks_stats_mean, label='KS Statistic Mean', alpha=0.7, color='green')
plt.axhline(mean_ks_stat_psmf, color='orange', linestyle='--', label='Mean KS Statistic PSMF')
plt.axhline(mean_ks_stat_mean, color='green', linestyle='--', label='Mean KS Statistic Mean')
plt.xlabel('Stock Number (Ordinal)')
plt.ylabel('KS Statistic')
plt.title('KS Statistic Comparison for Mean and PSMF Imputed Data')
plt.legend()

# Plot P-values for KS tests with ordinal stock number and mean lines
plt.subplot(2, 1, 2)
plt.plot(range(1, len(ks_pvalues_psmf) + 1), ks_pvalues_psmf, label='P-value PSMF', alpha=0.7, color='orange')
plt.plot(range(1, len(ks_pvalues_mean) + 1), ks_pvalues_mean, label='P-value Mean', alpha=0.7, color='green')
plt.axhline(0.05, color='red', linestyle='--', label='Significance Level (0.05)')
plt.xlabel('Stock Number (Ordinal)')
plt.ylabel('P-value')
plt.title('P-value Comparison for Mean and PSMF Imputed Data')
plt.legend()
plt.tight_layout()
#plt.show()

# Plot Hellinger distances with ordinal stock number and mean lines
plt.figure(figsize=(12, 6))
plt.plot(range(1, len(hellinger_psmf_list) + 1), hellinger_psmf_list, label='PSMF Imputed', alpha=0.7, color='orange')
plt.plot(range(1, len(hellinger_mean_list) + 1), hellinger_mean_list, label='Mean Imputed', alpha=0.7, color='green')
plt.axhline(mean_hellinger_psmf, color='orange', linestyle='--', label='Mean PSMF')
plt.axhline(mean_hellinger_mean, color='green', linestyle='--', label='Mean Imputed')
plt.xlabel('Stock Number (Ordinal)')
plt.ylabel('Hellinger Distance')
plt.title('Hellinger Distance Comparison for Mean and PSMF Imputed Data')
plt.legend()
#plt.show()
# Out:
# Stock 1 - KS Statistic PSMF: 0.0600745587305929, P-value PSMF: 0.029960961197342838
# Stock 1 - KS Statistic Mean: 0.09745086089709437, P-value Mean: 3.301516589056364e-05
# Stock 1 - Wasserstein Distance PSMF: 1.233841302963075
# Stock 1 - Wasserstein Distance Mean: 1.4609529017179708
# Stock 1 - Hellinger Distance PSMF: 0.06402207206804095
# Stock 1 - Hellinger Distance Mean: 0.19776024478209545
#
# ================================================================================
#
# Stock 2 - KS Statistic PSMF: 0.036623252524625366, P-value PSMF: 0.41352540563544743
# Stock 2 - KS Statistic Mean: 0.08522811164761478, P-value Mean: 0.00045332320275818535
# Stock 2 - Wasserstein Distance PSMF: 1.5752919523206765
# Stock 2 - Wasserstein Distance Mean: 4.16556576636635
# Stock 2 - Hellinger Distance PSMF: 0.0722992262965
# Stock 2 - Hellinger Distance Mean: 0.11465919429416821
#
# ================================================================================
#
# Stock 3 - KS Statistic PSMF: 0.03539091070707811, P-value PSMF: 0.4594592167259047
# Stock 3 - KS Statistic Mean: 0.09614083116451082, P-value Mean: 4.8362856288817036e-05
# Stock 3 - Wasserstein Distance PSMF: 1.5061060796161514
# Stock 3 - Wasserstein Distance Mean: 4.368066515774345
# Stock 3 - Hellinger Distance PSMF: 0.1194686792268528
# Stock 3 - Hellinger Distance Mean: 0.14155912662379205
#
# ================================================================================
#
# Stock 4 - KS Statistic PSMF: 0.03265802869961876, P-value PSMF: 0.5634300318508859
# Stock 4 - KS Statistic Mean: 0.09199595444082681, P-value Mean: 0.00011951742722435114
# Stock 4 - Wasserstein Distance PSMF: 1.055391018785507
# Stock 4 - Wasserstein Distance Mean: 1.5485395594793618
# Stock 4 - Hellinger Distance PSMF: 0.08403994895381922
# Stock 4 - Hellinger Distance Mean: 0.13859640692634936
#
# ================================================================================
#
# Stock 5 - KS Statistic PSMF: 0.04146569064230663, P-value PSMF: 0.2777305363317812
# Stock 5 - KS Statistic Mean: 0.09815536389469298, P-value Mean: 3.531529640920034e-05
# Stock 5 - Wasserstein Distance PSMF: 1.4200315746749381
# Stock 5 - Wasserstein Distance Mean: 2.7694257635374653
# Stock 5 - Hellinger Distance PSMF: 0.07444898939573211
# Stock 5 - Hellinger Distance Mean: 0.19854746610777632
#
# ================================================================================
#
# Stock 6 - KS Statistic PSMF: 0.02810897898765254, P-value PSMF: 0.739989363266078
# Stock 6 - KS Statistic Mean: 0.08810127686716249, P-value Mean: 0.00024673798307510116
# Stock 6 - Wasserstein Distance PSMF: 0.3442102907925805
# Stock 6 - Wasserstein Distance Mean: 0.7812947900432543
# Stock 6 - Hellinger Distance PSMF: 0.09303563695990859
# Stock 6 - Hellinger Distance Mean: 0.2365493659791059
#
# ================================================================================
#
# Stock 7 - KS Statistic PSMF: 0.024382072837943046, P-value PSMF: 0.8819633461138423
# Stock 7 - KS Statistic Mean: 0.10358763437900581, P-value Mean: 1.074963003940141e-05
# Stock 7 - Wasserstein Distance PSMF: 0.7618421226070031
# Stock 7 - Wasserstein Distance Mean: 3.6605323039316415
# Stock 7 - Hellinger Distance PSMF: 0.07467400265919044
# Stock 7 - Hellinger Distance Mean: 0.17997199375592082
#
# ================================================================================
#
# Stock 8 - KS Statistic PSMF: 0.03496745355363306, P-value PSMF: 0.4893421671541324
# Stock 8 - KS Statistic Mean: 0.1304402098683274, P-value Mean: 1.0001590417553462e-08
# Stock 8 - Wasserstein Distance PSMF: 2.3565197794875394
# Stock 8 - Wasserstein Distance Mean: 6.335287044915574
# Stock 8 - Hellinger Distance PSMF: 0.058177400781771534
# Stock 8 - Hellinger Distance Mean: 0.12505202252705327
#
# ================================================================================
#
# Stock 9 - KS Statistic PSMF: 0.06207715515482204, P-value PSMF: 0.025071703590163797
# Stock 9 - KS Statistic Mean: 0.12407111485054642, P-value Mean: 5.4509268961279535e-08
# Stock 9 - Wasserstein Distance PSMF: 1.0941212384102372
# Stock 9 - Wasserstein Distance Mean: 1.9773324526655427
# Stock 9 - Hellinger Distance PSMF: 0.12880999976525975
# Stock 9 - Hellinger Distance Mean: 0.20803558761187818
#
# ================================================================================
#
# Stock 10 - KS Statistic PSMF: 0.022578942896717726, P-value PSMF: 0.927939132977216
# Stock 10 - KS Statistic Mean: 0.10158068969172693, P-value Mean: 1.616081352357943e-05
# Stock 10 - Wasserstein Distance PSMF: 0.12461793147138131
# Stock 10 - Wasserstein Distance Mean: 0.7541808689567981
# Stock 10 - Hellinger Distance PSMF: 0.08799454567345812
# Stock 10 - Hellinger Distance Mean: 0.2921366521270902
#
# ================================================================================
#
# Stock 11 - KS Statistic PSMF: 0.044952918192126504, P-value PSMF: 0.19487037833018658
# Stock 11 - KS Statistic Mean: 0.10669920980987425, P-value Mean: 4.5001976304640705e-06
# Stock 11 - Wasserstein Distance PSMF: 0.8734926032859937
# Stock 11 - Wasserstein Distance Mean: 1.9642606710703863
# Stock 11 - Hellinger Distance PSMF: 0.0668681971447544
# Stock 11 - Hellinger Distance Mean: 0.15481682746216976
#
# ================================================================================
#
# Stock 12 - KS Statistic PSMF: 0.04642955559620875, P-value PSMF: 0.16708634820364074
# Stock 12 - KS Statistic Mean: 0.12178978024887477, P-value Mean: 8.812514863350379e-08
# Stock 12 - Wasserstein Distance PSMF: 1.6073947943755673
# Stock 12 - Wasserstein Distance Mean: 3.54517672485992
# Stock 12 - Hellinger Distance PSMF: 0.048873325539859326
# Stock 12 - Hellinger Distance Mean: 0.1904904736591742
#
# ================================================================================
#
# Stock 13 - KS Statistic PSMF: 0.025139904481587868, P-value PSMF: 0.8589137678740898
# Stock 13 - KS Statistic Mean: 0.10489392134805811, P-value Mean: 7.958745121263141e-06
# Stock 13 - Wasserstein Distance PSMF: 1.041828493085718
# Stock 13 - Wasserstein Distance Mean: 5.846659621256216
# Stock 13 - Hellinger Distance PSMF: 0.038597604027155036
# Stock 13 - Hellinger Distance Mean: 0.11764272131988086
#
# ================================================================================
#
# Stock 14 - KS Statistic PSMF: 0.045071945645575824, P-value PSMF: 0.1951599355379181
# Stock 14 - KS Statistic Mean: 0.10642899610037591, P-value Mean: 5.184776739235631e-06
# Stock 14 - Wasserstein Distance PSMF: 0.5039933859801644
# Stock 14 - Wasserstein Distance Mean: 1.335241766370648
# Stock 14 - Hellinger Distance PSMF: 0.08864027689727029
# Stock 14 - Hellinger Distance Mean: 0.31339154291698995
#
# ================================================================================
#
# Stock 15 - KS Statistic PSMF: 0.02170286134950309, P-value PSMF: 0.9457826315983794
# Stock 15 - KS Statistic Mean: 0.09973071930878165, P-value Mean: 2.3770229911325066e-05
# Stock 15 - Wasserstein Distance PSMF: 0.23094248842753487
# Stock 15 - Wasserstein Distance Mean: 1.3812315431215298
# Stock 15 - Hellinger Distance PSMF: 0.09783966531859582
# Stock 15 - Hellinger Distance Mean: 0.2609028070784556
#
# ================================================================================
#
# Stock 16 - KS Statistic PSMF: 0.04696039557884325, P-value PSMF: 0.1627678313317493
# Stock 16 - KS Statistic Mean: 0.1041541615364411, P-value Mean: 9.648728752616244e-06
# Stock 16 - Wasserstein Distance PSMF: 0.0908026751429191
# Stock 16 - Wasserstein Distance Mean: 0.25867811945560615
# Stock 16 - Hellinger Distance PSMF: 0.20259502025226703
# Stock 16 - Hellinger Distance Mean: 0.6436630673756153
#
# ================================================================================
#
# Stock 17 - KS Statistic PSMF: 0.03972876768746507, P-value PSMF: 0.3229829219387037
# Stock 17 - KS Statistic Mean: 0.10624246168328774, P-value Mean: 5.132059848551441e-06
# Stock 17 - Wasserstein Distance PSMF: 1.9163491533652124
# Stock 17 - Wasserstein Distance Mean: 4.923255866260506
# Stock 17 - Hellinger Distance PSMF: 0.054914524562856115
# Stock 17 - Hellinger Distance Mean: 0.10891690867365178
#
# ================================================================================
#
# Stock 18 - KS Statistic PSMF: 0.06471824951081993, P-value PSMF: 0.017086387062176845
# Stock 18 - KS Statistic Mean: 0.11437962253627923, P-value Mean: 7.314353527645091e-07
# Stock 18 - Wasserstein Distance PSMF: 1.0290104312911716
# Stock 18 - Wasserstein Distance Mean: 1.4167377887121717
# Stock 18 - Hellinger Distance PSMF: 0.11748025995995162
# Stock 18 - Hellinger Distance Mean: 0.2727326630963236
#
# ================================================================================
#
# Stock 19 - KS Statistic PSMF: 0.023248342272715102, P-value PSMF: 0.9038182518904382
# Stock 19 - KS Statistic Mean: 0.08096759511293965, P-value Mean: 0.0009496644468847221
# Stock 19 - Wasserstein Distance PSMF: 2.3754537347447835
# Stock 19 - Wasserstein Distance Mean: 6.994552491012234
# Stock 19 - Hellinger Distance PSMF: 0.052721336316820785
# Stock 19 - Hellinger Distance Mean: 0.07098727853525026
#
# ================================================================================
#
# Stock 20 - KS Statistic PSMF: 0.02667330652373775, P-value PSMF: 0.8050123474068961
# Stock 20 - KS Statistic Mean: 0.09840487075731896, P-value Mean: 3.381331684399612e-05
# Stock 20 - Wasserstein Distance PSMF: 0.3381326943730632
# Stock 20 - Wasserstein Distance Mean: 1.0489483398247972
# Stock 20 - Hellinger Distance PSMF: 0.09007000431280836
# Stock 20 - Hellinger Distance Mean: 0.25523142245162705
#
# ================================================================================
#
# Stock 21 - KS Statistic PSMF: 0.04883358338481452, P-value PSMF: 0.13450717193313094
# Stock 21 - KS Statistic Mean: 0.11824374016590061, P-value Mean: 3.012837647029184e-07
# Stock 21 - Wasserstein Distance PSMF: 0.4195060874922588
# Stock 21 - Wasserstein Distance Mean: 1.0588104661727133
# Stock 21 - Hellinger Distance PSMF: 0.11566443426484792
# Stock 21 - Hellinger Distance Mean: 0.3752030250258545
#
# ================================================================================
#
# Stock 22 - KS Statistic PSMF: 0.032486174940990376, P-value PSMF: 0.5628942807568085
# Stock 22 - KS Statistic Mean: 0.08019020825738005, P-value Mean: 0.0011281898359523216
# Stock 22 - Wasserstein Distance PSMF: 0.6514160930767859
# Stock 22 - Wasserstein Distance Mean: 2.3272669155677908
# Stock 22 - Hellinger Distance PSMF: 0.060956786820672695
# Stock 22 - Hellinger Distance Mean: 0.1966626767974803
#
# ================================================================================
# /var/folders/yq/q32slrvj24v6_3v1bf5lmwfw0000gn/T/ipykernel_17390/3809711582.py:88: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(18, 6))
# Stock 23 - KS Statistic PSMF: 0.025322146564155556, P-value PSMF: 0.848213411194974
# Stock 23 - KS Statistic Mean: 0.1227318645557809, P-value Mean: 6.658913481621955e-08
# Stock 23 - Wasserstein Distance PSMF: 0.25954323111480293
# Stock 23 - Wasserstein Distance Mean: 0.8637778102291649
# Stock 23 - Hellinger Distance PSMF: 0.12552574117633197
# Stock 23 - Hellinger Distance Mean: 0.2142903902589818
#
# ================================================================================
#
# Stock 24 - KS Statistic PSMF: 0.023242853571704327, P-value PSMF: 0.9085959898950895
# Stock 24 - KS Statistic Mean: 0.09350959902943275, P-value Mean: 8.663527323136035e-05
# Stock 24 - Wasserstein Distance PSMF: 0.5484508831705693
# Stock 24 - Wasserstein Distance Mean: 1.4848874620464134
# Stock 24 - Hellinger Distance PSMF: 0.06668521405993724
# Stock 24 - Hellinger Distance Mean: 0.2472992311723849
#
# ================================================================================
#
# Stock 25 - KS Statistic PSMF: 0.05337442794729394, P-value PSMF: 0.07931555619050552
# Stock 25 - KS Statistic Mean: 0.1267048734653862, P-value Mean: 2.824631801796528e-08
# Stock 25 - Wasserstein Distance PSMF: 2.4804622630428956
# Stock 25 - Wasserstein Distance Mean: 4.159570930810516
# Stock 25 - Hellinger Distance PSMF: 0.1806067543789129
# Stock 25 - Hellinger Distance Mean: 0.17798444687790146
#
# ================================================================================
#
# Stock 26 - KS Statistic PSMF: 0.03505930915256901, P-value PSMF: 0.4748615099872396
# Stock 26 - KS Statistic Mean: 0.12330695231000231, P-value Mean: 5.6584844182511245e-08
# Stock 26 - Wasserstein Distance PSMF: 1.4897696278903396
# Stock 26 - Wasserstein Distance Mean: 7.311631439752558
# Stock 26 - Hellinger Distance PSMF: 0.055310612900991304
# Stock 26 - Hellinger Distance Mean: 0.0971066290777932
#
# ================================================================================
#
# Stock 27 - KS Statistic PSMF: 0.055005760327444204, P-value PSMF: 0.06550702403819021
# Stock 27 - KS Statistic Mean: 0.1198974987696195, P-value Mean: 1.9364736688923683e-07
# Stock 27 - Wasserstein Distance PSMF: 1.8560172306670901
# Stock 27 - Wasserstein Distance Mean: 3.6931607974571508
# Stock 27 - Hellinger Distance PSMF: 0.08088331143333806
# Stock 27 - Hellinger Distance Mean: 0.22785184704194725
#
# ================================================================================
#
# Stock 28 - KS Statistic PSMF: 0.15542427077733528, P-value PSMF: 3.365570430807733e-11
# Stock 28 - KS Statistic Mean: 0.16649212322333065, P-value Mean: 8.622895996386897e-13
# Stock 28 - Wasserstein Distance PSMF: 2.953912849421646
# Stock 28 - Wasserstein Distance Mean: 2.763012552948139
# Stock 28 - Hellinger Distance PSMF: 0.22955989176101196
# Stock 28 - Hellinger Distance Mean: 0.31822937942254603
#
# ================================================================================
#
# Stock 29 - KS Statistic PSMF: 0.03545246502410368, P-value PSMF: 0.4678134233271989
# Stock 29 - KS Statistic Mean: 0.11474925093780228, P-value Mean: 6.866122842882947e-07
# Stock 29 - Wasserstein Distance PSMF: 0.6887974976055443
# Stock 29 - Wasserstein Distance Mean: 2.160424377307618
# Stock 29 - Hellinger Distance PSMF: 0.10245158269912051
# Stock 29 - Hellinger Distance Mean: 0.1817740594505117
#
# ================================================================================
#
# Stock 30 - KS Statistic PSMF: 0.05674209854888828, P-value PSMF: 0.05121380162404998
# Stock 30 - KS Statistic Mean: 0.10531556798944931, P-value Mean: 7.007167114318406e-06
# Stock 30 - Wasserstein Distance PSMF: 1.6406489292593938
# Stock 30 - Wasserstein Distance Mean: 4.979639382551621
# Stock 30 - Hellinger Distance PSMF: 0.049597783329967296
# Stock 30 - Hellinger Distance Mean: 0.1411708303976107
#
# ================================================================================
#
# Stock 31 - KS Statistic PSMF: 0.028240313387255404, P-value PSMF: 0.751442289610173
# Stock 31 - KS Statistic Mean: 0.14098292096703535, P-value Mean: 4.0145754187485085e-10
# Stock 31 - Wasserstein Distance PSMF: 0.4822905939296893
# Stock 31 - Wasserstein Distance Mean: 1.9307068456214105
# Stock 31 - Hellinger Distance PSMF: 0.12070347791300222
# Stock 31 - Hellinger Distance Mean: 0.269162219571779
#
# ================================================================================
#
# Stock 32 - KS Statistic PSMF: 0.034967227063068755, P-value PSMF: 0.48518505124023864
# Stock 32 - KS Statistic Mean: 0.14203727229231433, P-value Mean: 2.4624542696219664e-10
# Stock 32 - Wasserstein Distance PSMF: 0.21434048983744344
# Stock 32 - Wasserstein Distance Mean: 0.6929226289771372
# Stock 32 - Hellinger Distance PSMF: 0.8464716984020481
# Stock 32 - Hellinger Distance Mean: 0.5790116837882079
#
# ================================================================================
#
# Stock 33 - KS Statistic PSMF: 0.030179681716968637, P-value PSMF: 0.6564419432145254
# Stock 33 - KS Statistic Mean: 0.09566959104279059, P-value Mean: 4.888959915496773e-05
# Stock 33 - Wasserstein Distance PSMF: 0.484124439763295
# Stock 33 - Wasserstein Distance Mean: 0.8891325828025585
# Stock 33 - Hellinger Distance PSMF: 0.21625525557722836
# Stock 33 - Hellinger Distance Mean: 0.16512268987001363
#
# ================================================================================
#
# Stock 34 - KS Statistic PSMF: 0.030733052729012528, P-value PSMF: 0.647698951111691
# Stock 34 - KS Statistic Mean: 0.11987157036268004, P-value Mean: 1.6746939068180426e-07
# Stock 34 - Wasserstein Distance PSMF: 1.351314837916783
# Stock 34 - Wasserstein Distance Mean: 4.043149083417855
# Stock 34 - Hellinger Distance PSMF: 0.06962140809586229
# Stock 34 - Hellinger Distance Mean: 0.14336802508233032
#
# ================================================================================
#
# Stock 35 - KS Statistic PSMF: 0.02840156930704985, P-value PSMF: 0.7378796443439335
# Stock 35 - KS Statistic Mean: 0.0952826841268769, P-value Mean: 6.438446256331126e-05
# Stock 35 - Wasserstein Distance PSMF: 0.8898866237659675
# Stock 35 - Wasserstein Distance Mean: 4.214462161326763
# Stock 35 - Hellinger Distance PSMF: 0.04252556715653572
# Stock 35 - Hellinger Distance Mean: 0.15411226817917284
#
# ================================================================================
#
# Stock 36 - KS Statistic PSMF: 0.061402238855609075, P-value PSMF: 0.02735228738162478
# Stock 36 - KS Statistic Mean: 0.10597197713409266, P-value Mean: 5.9090957129065374e-06
# Stock 36 - Wasserstein Distance PSMF: 2.328867693041362
# Stock 36 - Wasserstein Distance Mean: 3.4295609234709343
# Stock 36 - Hellinger Distance PSMF: 0.05900393175285332
# Stock 36 - Hellinger Distance Mean: 0.13808724485765766
#
# ================================================================================
#
# Stock 37 - KS Statistic PSMF: 0.02665516490958472, P-value PSMF: 0.8069705779476748
# Stock 37 - KS Statistic Mean: 0.11748762029117359, P-value Mean: 3.3182503906367234e-07
# Stock 37 - Wasserstein Distance PSMF: 0.7228133186775707
# Stock 37 - Wasserstein Distance Mean: 3.1393029784794577
# Stock 37 - Hellinger Distance PSMF: 0.07405891601675946
# Stock 37 - Hellinger Distance Mean: 0.17939050873734244
#
# ================================================================================
#
# Stock 38 - KS Statistic PSMF: 0.0440728234543797, P-value PSMF: 0.21662238183762644
# Stock 38 - KS Statistic Mean: 0.11341865660838026, P-value Mean: 9.295950162886636e-07
# Stock 38 - Wasserstein Distance PSMF: 13.19454970516168
# Stock 38 - Wasserstein Distance Mean: 46.197958852026346
# Stock 38 - Hellinger Distance PSMF: 0.054416554988615716
# Stock 38 - Hellinger Distance Mean: 0.04744235348484686
#
# ================================================================================
#
# Stock 39 - KS Statistic PSMF: 0.024921141395717564, P-value PSMF: 0.8580450682862144
# Stock 39 - KS Statistic Mean: 0.090737132417151, P-value Mean: 0.0001502712669940513
# Stock 39 - Wasserstein Distance PSMF: 0.7683005035254702
# Stock 39 - Wasserstein Distance Mean: 2.7221453389751846
# Stock 39 - Hellinger Distance PSMF: 0.05037362849558171
# Stock 39 - Hellinger Distance Mean: 0.16450255403613226
#
# ================================================================================
#
# Stock 40 - KS Statistic PSMF: 0.019839480428713457, P-value PSMF: 0.9740188035759377
# Stock 40 - KS Statistic Mean: 0.12524921430255476, P-value Mean: 2.9627917796507133e-08
# Stock 40 - Wasserstein Distance PSMF: 0.654473874586444
# Stock 40 - Wasserstein Distance Mean: 2.5008174429350376
# Stock 40 - Hellinger Distance PSMF: 0.059019665944766854
# Stock 40 - Hellinger Distance Mean: 0.13130330684630898
#
# ================================================================================
#
# Stock 41 - KS Statistic PSMF: 0.03799236406960792, P-value PSMF: 0.3663076036888692
# Stock 41 - KS Statistic Mean: 0.08504750643849135, P-value Mean: 0.00045462061032301834
# Stock 41 - Wasserstein Distance PSMF: 2.0073569674304634
# Stock 41 - Wasserstein Distance Mean: 5.07191532171305
# Stock 41 - Hellinger Distance PSMF: 0.06257869303427674
# Stock 41 - Hellinger Distance Mean: 0.09423030733763148
#
# ================================================================================
#
# Stock 42 - KS Statistic PSMF: 0.09671660703055876, P-value PSMF: 4.850687112837911e-05
# Stock 42 - KS Statistic Mean: 0.1056768477180411, P-value Mean: 6.212585119292579e-06
# Stock 42 - Wasserstein Distance PSMF: 3.8750217011710455
# Stock 42 - Wasserstein Distance Mean: 3.452019194661902
# Stock 42 - Hellinger Distance PSMF: 0.06910013901756931
# Stock 42 - Hellinger Distance Mean: 0.1675559723259931
#
# ================================================================================
#
# Stock 43 - KS Statistic PSMF: 0.06168183140792236, P-value PSMF: 0.02662355430740855
# Stock 43 - KS Statistic Mean: 0.11239943692542408, P-value Mean: 1.2543604912890993e-06
# Stock 43 - Wasserstein Distance PSMF: 0.8229784109334777
# Stock 43 - Wasserstein Distance Mean: 2.170475702867985
# Stock 43 - Hellinger Distance PSMF: 0.14907556706259337
# Stock 43 - Hellinger Distance Mean: 0.21711171083879174
#
# ================================================================================
#
# Stock 44 - KS Statistic PSMF: 0.06163511165821227, P-value PSMF: 0.027169097966582206
# Stock 44 - KS Statistic Mean: 0.116199222174052, P-value Mean: 4.945640432699593e-07
# Stock 44 - Wasserstein Distance PSMF: 1.918564844737009
# Stock 44 - Wasserstein Distance Mean: 2.9402076309756113
# Stock 44 - Hellinger Distance PSMF: 0.08421239322906081
# Stock 44 - Hellinger Distance Mean: 0.18429920782423587
#
# ================================================================================
#
# Stock 45 - KS Statistic PSMF: 0.05224412066125882, P-value PSMF: 0.09024953761044363
# Stock 45 - KS Statistic Mean: 0.10107583253457808, P-value Mean: 1.9691757651995807e-05
# Stock 45 - Wasserstein Distance PSMF: 2.091438065163888
# Stock 45 - Wasserstein Distance Mean: 3.4412190862832137
# Stock 45 - Hellinger Distance PSMF: 0.0659285998905484
# Stock 45 - Hellinger Distance Mean: 0.18967692531924688
#
# ================================================================================
#
# Stock 46 - KS Statistic PSMF: 0.07354935092335187, P-value PSMF: 0.004153989506960863
# Stock 46 - KS Statistic Mean: 0.12376901931096108, P-value Mean: 5.304211387090479e-08
# Stock 46 - Wasserstein Distance PSMF: 2.080251533621576
# Stock 46 - Wasserstein Distance Mean: 3.2205641703344314
# Stock 46 - Hellinger Distance PSMF: 0.08693572185642526
# Stock 46 - Hellinger Distance Mean: 0.1611466781625279
#
# ================================================================================
#
# Stock 47 - KS Statistic PSMF: 0.019613408579938176, P-value PSMF: 0.9775329947893144
# Stock 47 - KS Statistic Mean: 0.10711890938311344, P-value Mean: 4.118174715032049e-06
# Stock 47 - Wasserstein Distance PSMF: 0.49285951842163
# Stock 47 - Wasserstein Distance Mean: 2.0009487868545626
# Stock 47 - Hellinger Distance PSMF: 0.09413528756454209
# Stock 47 - Hellinger Distance Mean: 0.17539885303245853
#
# ================================================================================
#
# Stock 48 - KS Statistic PSMF: 0.7950754567116759, P-value PSMF: 5.522142164032188e-29
# Stock 48 - KS Statistic Mean: 0.5044588056899415, P-value Mean: 1.5901663749380204e-10
# Stock 48 - Wasserstein Distance PSMF: 23.038694943968743
# Stock 48 - Wasserstein Distance Mean: 3.7290970713343268
# Stock 48 - Hellinger Distance PSMF: 1.1563980138187997
# Stock 48 - Hellinger Distance Mean: 1.770414754750674
#
# ================================================================================
#
# Stock 49 - KS Statistic PSMF: 0.05502188317826489, P-value PSMF: 0.061593552839141114
# Stock 49 - KS Statistic Mean: 0.0995940768657711, P-value Mean: 2.3645585043457274e-05
# Stock 49 - Wasserstein Distance PSMF: 1.12900031304057
# Stock 49 - Wasserstein Distance Mean: 2.9677849304819945
# Stock 49 - Hellinger Distance PSMF: 0.10126392577388985
# Stock 49 - Hellinger Distance Mean: 0.16250605518225966
#
# ================================================================================
#
# Stock 50 - KS Statistic PSMF: 0.031027246751185726, P-value PSMF: 0.6376795643615406
# Stock 50 - KS Statistic Mean: 0.13034696181558064, P-value Mean: 9.036829359392548e-09
# Stock 50 - Wasserstein Distance PSMF: 0.4044994346609006
# Stock 50 - Wasserstein Distance Mean: 1.4566291975309498
# Stock 50 - Hellinger Distance PSMF: 0.09478828221535512
# Stock 50 - Hellinger Distance Mean: 0.29458840187210594
#
# ================================================================================
#
# Stock 51 - KS Statistic PSMF: 0.031466989169796525, P-value PSMF: 0.6107178221752777
# Stock 51 - KS Statistic Mean: 0.09350959902943275, P-value Mean: 8.663527323136035e-05
# Stock 51 - Wasserstein Distance PSMF: 0.9424815851885273
# Stock 51 - Wasserstein Distance Mean: 2.28428314452786
# Stock 51 - Hellinger Distance PSMF: 0.07610748657507314
# Stock 51 - Hellinger Distance Mean: 0.20478559827997606
#
# ================================================================================
#
# Stock 52 - KS Statistic PSMF: 0.02704712119253006, P-value PSMF: 0.7871412177530285
# Stock 52 - KS Statistic Mean: 0.11286335285171571, P-value Mean: 9.3950397714151e-07
# Stock 52 - Wasserstein Distance PSMF: 0.7285611265169447
# Stock 52 - Wasserstein Distance Mean: 3.325266742157029
# Stock 52 - Hellinger Distance PSMF: 0.04555496407593816
# Stock 52 - Hellinger Distance Mean: 0.17203250506695622
#
# ================================================================================
#
# Stock 53 - KS Statistic PSMF: 0.031358816717070456, P-value PSMF: 0.6237274011973234
# Stock 53 - KS Statistic Mean: 0.10357959708852432, P-value Mean: 1.0557401597577807e-05
# Stock 53 - Wasserstein Distance PSMF: 2.9991599920448104
# Stock 53 - Wasserstein Distance Mean: 11.32048108870578
# Stock 53 - Hellinger Distance PSMF: 0.06041133899006866
# Stock 53 - Hellinger Distance Mean: 0.07949192656820435
#
# ================================================================================
#
# Stock 54 - KS Statistic PSMF: 0.04144554487922943, P-value PSMF: 0.2785268137657907
# Stock 54 - KS Statistic Mean: 0.11661484704425092, P-value Mean: 3.9793780255542703e-07
# Stock 54 - Wasserstein Distance PSMF: 0.9668191887680975
# Stock 54 - Wasserstein Distance Mean: 3.0342486435895832
# Stock 54 - Hellinger Distance PSMF: 0.08358538167183778
# Stock 54 - Hellinger Distance Mean: 0.16404726565409417
#
# ================================================================================
#
# Stock 55 - KS Statistic PSMF: 0.030589511613940603, P-value PSMF: 0.6505327536968628
# Stock 55 - KS Statistic Mean: 0.1069838625312385, P-value Mean: 4.3164670435250995e-06
# Stock 55 - Wasserstein Distance PSMF: 0.44820705390444443
# Stock 55 - Wasserstein Distance Mean: 2.5967564847695046
# Stock 55 - Hellinger Distance PSMF: 0.07943151570349825
# Stock 55 - Hellinger Distance Mean: 0.25224001379374394
#
# ================================================================================
#
# Stock 56 - KS Statistic PSMF: 0.03291854205277557, P-value PSMF: 0.5607874734082403
# Stock 56 - KS Statistic Mean: 0.09960457762126455, P-value Mean: 2.5670896312573495e-05
# Stock 56 - Wasserstein Distance PSMF: 0.5546791524926872
# Stock 56 - Wasserstein Distance Mean: 1.8452352748873466
# Stock 56 - Hellinger Distance PSMF: 0.07072229237279803
# Stock 56 - Hellinger Distance Mean: 0.2134708193586682
#
# ================================================================================
#
# Stock 57 - KS Statistic PSMF: 0.08251306262223404, P-value PSMF: 0.00081270596405139
# Stock 57 - KS Statistic Mean: 0.09177634762783395, P-value Mean: 0.0001284073851264998
# Stock 57 - Wasserstein Distance PSMF: 9.052392459776675
# Stock 57 - Wasserstein Distance Mean: 8.442228696520758
# Stock 57 - Hellinger Distance PSMF: 0.051093567445381544
# Stock 57 - Hellinger Distance Mean: 0.12367546367868529
#
# ================================================================================
#
# Stock 58 - KS Statistic PSMF: 0.051476279521498206, P-value PSMF: 0.09666131530387372
# Stock 58 - KS Statistic Mean: 0.1008323973183072, P-value Mean: 1.918935751665739e-05
# Stock 58 - Wasserstein Distance PSMF: 7.910065125935568
# Stock 58 - Wasserstein Distance Mean: 23.27801980413626
# Stock 58 - Hellinger Distance PSMF: 0.07149473216106259
# Stock 58 - Hellinger Distance Mean: 0.09667666175415371
#
# ================================================================================
#
# Stock 59 - KS Statistic PSMF: 0.05493949028760551, P-value PSMF: 0.06481954072167732
# Stock 59 - KS Statistic Mean: 0.1200555602442947, P-value Mean: 1.7149393493998752e-07
# Stock 59 - Wasserstein Distance PSMF: 0.7054198688121531
# Stock 59 - Wasserstein Distance Mean: 1.4539693088338863
# Stock 59 - Hellinger Distance PSMF: 0.08712984216650493
# Stock 59 - Hellinger Distance Mean: 0.2751874171606094
#
# ================================================================================
#
# Stock 60 - KS Statistic PSMF: 0.03580768176729884, P-value PSMF: 0.44960935556239834
# Stock 60 - KS Statistic Mean: 0.13347949345608306, P-value Mean: 3.0141126326387764e-09
# Stock 60 - Wasserstein Distance PSMF: 0.21878168002804085
# Stock 60 - Wasserstein Distance Mean: 0.6427639677600838
# Stock 60 - Hellinger Distance PSMF: 0.15591522927747295
# Stock 60 - Hellinger Distance Mean: 0.31228804002375843
#
# ================================================================================
#
# Stock 61 - KS Statistic PSMF: 0.02154373567783225, P-value PSMF: 0.9467895048767937
# Stock 61 - KS Statistic Mean: 0.10583188019440108, P-value Mean: 5.012391300841961e-06
# Stock 61 - Wasserstein Distance PSMF: 0.38145066149692464
# Stock 61 - Wasserstein Distance Mean: 2.0222302609654577
# Stock 61 - Hellinger Distance PSMF: 0.09020852706568944
# Stock 61 - Hellinger Distance Mean: 0.24904116816954505
#
# ================================================================================
#
# Stock 62 - KS Statistic PSMF: 0.05070675601687269, P-value PSMF: 0.10383715159811406
# Stock 62 - KS Statistic Mean: 0.1305019394341325, P-value Mean: 7.027565688429425e-09
# Stock 62 - Wasserstein Distance PSMF: 3.5710814339698773
# Stock 62 - Wasserstein Distance Mean: 5.821590867226421
# Stock 62 - Hellinger Distance PSMF: 0.0639795220192722
# Stock 62 - Hellinger Distance Mean: 0.0629663431181096
#
# ================================================================================
#
# Stock 63 - KS Statistic PSMF: 0.04059235794152815, P-value PSMF: 0.3001659525166145
# Stock 63 - KS Statistic Mean: 0.11979253780226055, P-value Mean: 1.6382034555891112e-07
# Stock 63 - Wasserstein Distance PSMF: 0.38323449827207223
# Stock 63 - Wasserstein Distance Mean: 0.7164552573093625
# Stock 63 - Hellinger Distance PSMF: 0.21845810388165146
# Stock 63 - Hellinger Distance Mean: 0.26340841273622184
#
# ================================================================================
#
# Stock 64 - KS Statistic PSMF: 0.028065619844809677, P-value PSMF: 0.7462388299992564
# Stock 64 - KS Statistic Mean: 0.1092190077595161, P-value Mean: 2.2296498772240294e-06
# Stock 64 - Wasserstein Distance PSMF: 0.49113102870847625
# Stock 64 - Wasserstein Distance Mean: 1.5749150425516165
# Stock 64 - Hellinger Distance PSMF: 0.06795176781165896
# Stock 64 - Hellinger Distance Mean: 0.17080984179563122
#
# ================================================================================
#
# Stock 65 - KS Statistic PSMF: 0.038984743150194935, P-value PSMF: 0.3446812043021444
# Stock 65 - KS Statistic Mean: 0.10353033620444968, P-value Mean: 9.74367601525899e-06
# Stock 65 - Wasserstein Distance PSMF: 1.6125766647195396
# Stock 65 - Wasserstein Distance Mean: 5.229814543668027
# Stock 65 - Hellinger Distance PSMF: 0.053046081710232666
# Stock 65 - Hellinger Distance Mean: 0.11388367181079716
#
# ================================================================================
#
# Stock 66 - KS Statistic PSMF: 0.03767909221543816, P-value PSMF: 0.3788726026181847
# Stock 66 - KS Statistic Mean: 0.0863553407830036, P-value Mean: 0.00036353411911422217
# Stock 66 - Wasserstein Distance PSMF: 0.2737391064176333
# Stock 66 - Wasserstein Distance Mean: 1.0925486302184668
# Stock 66 - Hellinger Distance PSMF: 0.09752441098107419
# Stock 66 - Hellinger Distance Mean: 0.30690658044508246
#
# ================================================================================
#
# Stock 67 - KS Statistic PSMF: 0.043451435379552934, P-value PSMF: 0.2322469365599331
# Stock 67 - KS Statistic Mean: 0.10996696798920787, P-value Mean: 2.344414119786744e-06
# Stock 67 - Wasserstein Distance PSMF: 0.3414907331622584
# Stock 67 - Wasserstein Distance Mean: 1.011804893623307
# Stock 67 - Hellinger Distance PSMF: 0.14412053632385038
# Stock 67 - Hellinger Distance Mean: 0.19655524833684107
#
# ================================================================================
#
# Stock 68 - KS Statistic PSMF: 0.8490865766481335, P-value PSMF: 8.930814587063989e-76
# Stock 68 - KS Statistic Mean: 0.5259529446239503, P-value Mean: 6.102737616077323e-25
# Stock 68 - Wasserstein Distance PSMF: 40.69557720048253
# Stock 68 - Wasserstein Distance Mean: 2.6603437329088973
# Stock 68 - Hellinger Distance PSMF: 0.9519953700105085
# Stock 68 - Hellinger Distance Mean: 1.2554849520150402
#
# ================================================================================
#
# Stock 69 - KS Statistic PSMF: 0.8788420343225745, P-value PSMF: 4.171944429816426e-104
# Stock 69 - KS Statistic Mean: 0.4611403952150576, P-value Mean: 1.1400588225196156e-23
# Stock 69 - Wasserstein Distance PSMF: 22.376567799568242
# Stock 69 - Wasserstein Distance Mean: 1.8911647086796912
# Stock 69 - Hellinger Distance PSMF: 0.8920492734075774
# Stock 69 - Hellinger Distance Mean: 0.8517140952595298
#
# ================================================================================
#
# Stock 70 - KS Statistic PSMF: 0.020451746424740864, P-value PSMF: 0.9690098232905839
# Stock 70 - KS Statistic Mean: 0.10914806784544671, P-value Mean: 3.068023240418634e-06
# Stock 70 - Wasserstein Distance PSMF: 2.3255157509646307
# Stock 70 - Wasserstein Distance Mean: 8.403243756342
# Stock 70 - Hellinger Distance PSMF: 0.02448042525472767
# Stock 70 - Hellinger Distance Mean: 0.07488864200185137
#
# ================================================================================
#
# Stock 71 - KS Statistic PSMF: 0.06909540547936398, P-value PSMF: 0.008837572296504195
# Stock 71 - KS Statistic Mean: 0.09933611266404102, P-value Mean: 2.7939143162407894e-05
# Stock 71 - Wasserstein Distance PSMF: 1.160104833816889
# Stock 71 - Wasserstein Distance Mean: 1.1191879686504516
# Stock 71 - Hellinger Distance PSMF: 0.3266648542524643
# Stock 71 - Hellinger Distance Mean: 0.26333444782883025
#
# ================================================================================
#
# Stock 72 - KS Statistic PSMF: 0.038961121566363825, P-value PSMF: 0.3543829831669256
# Stock 72 - KS Statistic Mean: 0.1124555850528845, P-value Mean: 1.3481290398833968e-06
# Stock 72 - Wasserstein Distance PSMF: 4.212753445508315
# Stock 72 - Wasserstein Distance Mean: 10.333052180840875
# Stock 72 - Hellinger Distance PSMF: 0.02446537876850114
# Stock 72 - Hellinger Distance Mean: 0.07343625198770726
#
# ================================================================================
#
# Stock 73 - KS Statistic PSMF: 0.03967508521569138, P-value PSMF: 0.3267158109953279
# Stock 73 - KS Statistic Mean: 0.11430166003986215, P-value Mean: 7.169094214201999e-07
# Stock 73 - Wasserstein Distance PSMF: 0.409889205788534
# Stock 73 - Wasserstein Distance Mean: 1.0375755022962085
# Stock 73 - Hellinger Distance PSMF: 0.11790913542480518
# Stock 73 - Hellinger Distance Mean: 0.32694871289086114
#
# ================================================================================
#
# Stock 74 - KS Statistic PSMF: 0.09653204855408563, P-value PSMF: 4.613093973491441e-05
# Stock 74 - KS Statistic Mean: 0.09747996245216262, P-value Mean: 3.7390406240029794e-05
# Stock 74 - Wasserstein Distance PSMF: 1.4525574740692127
# Stock 74 - Wasserstein Distance Mean: 1.198142810833565
# Stock 74 - Hellinger Distance PSMF: 0.11297395543261811
# Stock 74 - Hellinger Distance Mean: 0.24405631725622629
#
# ================================================================================
#
# Stock 75 - KS Statistic PSMF: 0.04398361824890816, P-value PSMF: 0.2228085582318237
# Stock 75 - KS Statistic Mean: 0.108734628194517, P-value Mean: 3.3942733956750196e-06
# Stock 75 - Wasserstein Distance PSMF: 1.398390626855471
# Stock 75 - Wasserstein Distance Mean: 3.677615950790793
# Stock 75 - Hellinger Distance PSMF: 0.0648310903133972
# Stock 75 - Hellinger Distance Mean: 0.10715962315399091
#
# ================================================================================
#
# Stock 76 - KS Statistic PSMF: 0.050871274714773936, P-value PSMF: 0.09969367938141414
# Stock 76 - KS Statistic Mean: 0.1007611100459831, P-value Mean: 1.67140672363328e-05
# Stock 76 - Wasserstein Distance PSMF: 0.31583519349237466
# Stock 76 - Wasserstein Distance Mean: 0.9245711381860007
# Stock 76 - Hellinger Distance PSMF: 0.21936032453138857
# Stock 76 - Hellinger Distance Mean: 0.2838053445323286
#
# ================================================================================
#
# Stock 77 - KS Statistic PSMF: 0.043879605155200695, P-value PSMF: 0.21674308657778332
# Stock 77 - KS Statistic Mean: 0.09924277500733805, P-value Mean: 2.56076494635661e-05
# Stock 77 - Wasserstein Distance PSMF: 0.7173703893737939
# Stock 77 - Wasserstein Distance Mean: 1.500028672779216
# Stock 77 - Hellinger Distance PSMF: 0.08576138505460099
# Stock 77 - Hellinger Distance Mean: 0.2857863715600723
#
# ================================================================================
#
# Stock 78 - KS Statistic PSMF: 0.044737944000527, P-value PSMF: 0.19423387457403982
# Stock 78 - KS Statistic Mean: 0.08809024972533318, P-value Mean: 0.00025575745233611817
# Stock 78 - Wasserstein Distance PSMF: 0.6767846261098035
# Stock 78 - Wasserstein Distance Mean: 1.3053812085698768
# Stock 78 - Hellinger Distance PSMF: 0.07808067634236936
# Stock 78 - Hellinger Distance Mean: 0.19296064725440723
#
# ================================================================================
#
# Stock 79 - KS Statistic PSMF: 0.05599051905644439, P-value PSMF: 0.05692211205971856
# Stock 79 - KS Statistic Mean: 0.11095587957184462, P-value Mean: 1.8326124680794211e-06
# Stock 79 - Wasserstein Distance PSMF: 0.4912698775067025
# Stock 79 - Wasserstein Distance Mean: 0.8344937924644749
# Stock 79 - Hellinger Distance PSMF: 0.12496511556808886
# Stock 79 - Hellinger Distance Mean: 0.3317733783765376
#
# ================================================================================
#
# Stock 80 - KS Statistic PSMF: 0.025953922500522756, P-value PSMF: 0.8253250115730966
# Stock 80 - KS Statistic Mean: 0.09964284155047974, P-value Mean: 2.2559919097758454e-05
# Stock 80 - Wasserstein Distance PSMF: 0.4657060326153037
# Stock 80 - Wasserstein Distance Mean: 1.6855585483788316
# Stock 80 - Hellinger Distance PSMF: 0.0575843266232233
# Stock 80 - Hellinger Distance Mean: 0.19317123584905507
#
# ================================================================================
#
# Stock 81 - KS Statistic PSMF: 0.024916952620932242, P-value PSMF: 0.8646899533071656
# Stock 81 - KS Statistic Mean: 0.1172374665951944, P-value Mean: 3.4285200846995834e-07
# Stock 81 - Wasserstein Distance PSMF: 0.7266173725493648
# Stock 81 - Wasserstein Distance Mean: 2.7035738645970433
# Stock 81 - Hellinger Distance PSMF: 0.06516015511118407
# Stock 81 - Hellinger Distance Mean: 0.12776091227563915
#
# ================================================================================
#
# Stock 82 - KS Statistic PSMF: 0.06931123578220999, P-value PSMF: 0.008567615192638387
# Stock 82 - KS Statistic Mean: 0.109725392195952, P-value Mean: 2.416503239498853e-06
# Stock 82 - Wasserstein Distance PSMF: 0.24525054077170558
# Stock 82 - Wasserstein Distance Mean: 0.38176778740196765
# Stock 82 - Hellinger Distance PSMF: 0.17945723496163224
# Stock 82 - Hellinger Distance Mean: 0.503003944406776
#
# ================================================================================
#
# Stock 83 - KS Statistic PSMF: 0.033472280828038124, P-value PSMF: 0.5368638075624229
# Stock 83 - KS Statistic Mean: 0.09515085137013503, P-value Mean: 6.595616459247781e-05
# Stock 83 - Wasserstein Distance PSMF: 0.3321773806853967
# Stock 83 - Wasserstein Distance Mean: 0.9004282809705182
# Stock 83 - Hellinger Distance PSMF: 0.08084950692186971
# Stock 83 - Hellinger Distance Mean: 0.31311048295685245
#
# ================================================================================
#
# Stock 84 - KS Statistic PSMF: 0.029132234148154915, P-value PSMF: 0.7112477881844298
# Stock 84 - KS Statistic Mean: 0.12398596379421166, P-value Mean: 5.329430479786297e-08
# Stock 84 - Wasserstein Distance PSMF: 0.7993104015061632
# Stock 84 - Wasserstein Distance Mean: 2.86854848510849
# Stock 84 - Hellinger Distance PSMF: 0.08746054387360266
# Stock 84 - Hellinger Distance Mean: 0.1278199145755987
#
# ================================================================================
#
# Stock 85 - KS Statistic PSMF: 0.030668819249674798, P-value PSMF: 0.6512652849605368
# Stock 85 - KS Statistic Mean: 0.10049342659799101, P-value Mean: 2.1512991337700358e-05
# Stock 85 - Wasserstein Distance PSMF: 0.3312959097737955
# Stock 85 - Wasserstein Distance Mean: 1.0515356498383168
# Stock 85 - Hellinger Distance PSMF: 0.09950879803612808
# Stock 85 - Hellinger Distance Mean: 0.2784373162111993
#
# ================================================================================
#
# Stock 86 - KS Statistic PSMF: 0.0358330715609145, P-value PSMF: 0.4510973820133527
# Stock 86 - KS Statistic Mean: 0.10681873630566496, P-value Mean: 4.685606801795784e-06
# Stock 86 - Wasserstein Distance PSMF: 0.70990795996253
# Stock 86 - Wasserstein Distance Mean: 3.0249186542034794
# Stock 86 - Hellinger Distance PSMF: 0.08444793470676946
# Stock 86 - Hellinger Distance Mean: 0.20296723752281778
#
# ================================================================================
#
# Stock 87 - KS Statistic PSMF: 0.037771548221429384, P-value PSMF: 0.3787668364841888
# Stock 87 - KS Statistic Mean: 0.09485506088597134, P-value Mean: 6.479883042755387e-05
# Stock 87 - Wasserstein Distance PSMF: 0.6547416142900533
# Stock 87 - Wasserstein Distance Mean: 1.5118415337475244
# Stock 87 - Hellinger Distance PSMF: 0.08200592664077491
# Stock 87 - Hellinger Distance Mean: 0.2285241342777635
#
# ================================================================================
#
# Stock 88 - KS Statistic PSMF: 0.048287486348292295, P-value PSMF: 0.13770360437111798
# Stock 88 - KS Statistic Mean: 0.10098385375297855, P-value Mean: 1.796437950720388e-05
# Stock 88 - Wasserstein Distance PSMF: 0.6258768231046217
# Stock 88 - Wasserstein Distance Mean: 1.475669370595191
# Stock 88 - Hellinger Distance PSMF: 0.08977634231479362
# Stock 88 - Hellinger Distance Mean: 0.21029559318994628
#
# ================================================================================
#
# Stock 89 - KS Statistic PSMF: 0.04717539507054996, P-value PSMF: 0.1528584923325277
# Stock 89 - KS Statistic Mean: 0.11061745394549206, P-value Mean: 1.6173409436029989e-06
# Stock 89 - Wasserstein Distance PSMF: 0.6692548044983799
# Stock 89 - Wasserstein Distance Mean: 1.107444508333843
# Stock 89 - Hellinger Distance PSMF: 0.16354419510299292
# Stock 89 - Hellinger Distance Mean: 0.301556146021212
#
# ================================================================================
#
# Stock 90 - KS Statistic PSMF: 0.0417414251651822, P-value PSMF: 0.26470740690242034
# Stock 90 - KS Statistic Mean: 0.10309601475727027, P-value Mean: 9.991307506229786e-06
# Stock 90 - Wasserstein Distance PSMF: 1.7351373671399717
# Stock 90 - Wasserstein Distance Mean: 3.4561347796284076
# Stock 90 - Hellinger Distance PSMF: 0.05517603682653377
# Stock 90 - Hellinger Distance Mean: 0.13299915061921075
#
# ================================================================================
#
# Stock 91 - KS Statistic PSMF: 0.04043097987642302, P-value PSMF: 0.2998302195093236
# Stock 91 - KS Statistic Mean: 0.08910042486766448, P-value Mean: 0.00022003831907998534
# Stock 91 - Wasserstein Distance PSMF: 0.3054135700275022
# Stock 91 - Wasserstein Distance Mean: 1.0928194299858447
# Stock 91 - Hellinger Distance PSMF: 0.09724386935600098
# Stock 91 - Hellinger Distance Mean: 0.24612552256731107
#
# ================================================================================
#
# Stock 92 - KS Statistic PSMF: 0.35380339350172396, P-value PSMF: 7.175003953693646e-51
# Stock 92 - KS Statistic Mean: 0.27906569165937356, P-value Mean: 1.469585630817585e-31
# Stock 92 - Wasserstein Distance PSMF: 19.40892363876033
# Stock 92 - Wasserstein Distance Mean: 2.4648764088152557
# Stock 92 - Hellinger Distance PSMF: 0.6329346935353112
# Stock 92 - Hellinger Distance Mean: 0.5988884076368329
#
# ================================================================================
#
# Stock 93 - KS Statistic PSMF: 0.03628560928479129, P-value PSMF: 0.4400316664604245
# Stock 93 - KS Statistic Mean: 0.1047882114447619, P-value Mean: 8.38439113065478e-06
# Stock 93 - Wasserstein Distance PSMF: 0.625736068389201
# Stock 93 - Wasserstein Distance Mean: 1.9620063501302543
# Stock 93 - Hellinger Distance PSMF: 0.08208413149355111
# Stock 93 - Hellinger Distance Mean: 0.26339501724774467
#
# ================================================================================
#
# Stock 94 - KS Statistic PSMF: 0.059459623780419836, P-value PSMF: 0.03537869521325176
# Stock 94 - KS Statistic Mean: 0.11243092910631286, P-value Mean: 1.1600977010305577e-06
# Stock 94 - Wasserstein Distance PSMF: 0.7101195761058647
# Stock 94 - Wasserstein Distance Mean: 1.1001044597764198
# Stock 94 - Hellinger Distance PSMF: 0.11112860830625126
# Stock 94 - Hellinger Distance Mean: 0.2662623175665404
#
# ================================================================================
#
# Stock 95 - KS Statistic PSMF: 0.049446755636643885, P-value PSMF: 0.12360768155770681
# Stock 95 - KS Statistic Mean: 0.10887471590685677, P-value Mean: 3.025411276791674e-06
# Stock 95 - Wasserstein Distance PSMF: 0.5062472382780963
# Stock 95 - Wasserstein Distance Mean: 1.685424744618864
# Stock 95 - Hellinger Distance PSMF: 0.15999181874298232
# Stock 95 - Hellinger Distance Mean: 0.3809563935811729
#
# ================================================================================
#
# Stock 96 - KS Statistic PSMF: 0.03958442831789159, P-value PSMF: 0.33190339848604344
# Stock 96 - KS Statistic Mean: 0.10365408622703871, P-value Mean: 1.0517583039431556e-05
# Stock 96 - Wasserstein Distance PSMF: 0.6556609055970892
# Stock 96 - Wasserstein Distance Mean: 1.2559806179978785
# Stock 96 - Hellinger Distance PSMF: 0.06365902881604417
# Stock 96 - Hellinger Distance Mean: 0.19585110898901006
#
# ================================================================================
#
# Stock 97 - KS Statistic PSMF: 0.03133898515720824, P-value PSMF: 0.6191340653502881
# Stock 97 - KS Statistic Mean: 0.11415572696796862, P-value Mean: 6.880049620889594e-07
# Stock 97 - Wasserstein Distance PSMF: 4.603191096660189
# Stock 97 - Wasserstein Distance Mean: 13.848675607293393
# Stock 97 - Hellinger Distance PSMF: 0.041637059782435946
# Stock 97 - Hellinger Distance Mean: 0.09964845266136865
#
# ================================================================================
#
# Stock 98 - KS Statistic PSMF: 0.06959802632234029, P-value PSMF: 0.00760673831444349
# Stock 98 - KS Statistic Mean: 0.10627436172192806, P-value Mean: 4.7254698134790805e-06
# Stock 98 - Wasserstein Distance PSMF: 1.413236210200421
# Stock 98 - Wasserstein Distance Mean: 1.730596238132925
# Stock 98 - Hellinger Distance PSMF: 0.09317215796353544
# Stock 98 - Hellinger Distance Mean: 0.3157396943017949
#
# ================================================================================
#
# Stock 99 - KS Statistic PSMF: 0.023330233057571963, P-value PSMF: 0.9116696684980747
# Stock 99 - KS Statistic Mean: 0.11186258146119313, P-value Mean: 1.482086081843629e-06
# Stock 99 - Wasserstein Distance PSMF: 1.2262812414264241
# Stock 99 - Wasserstein Distance Mean: 6.463831348070948
# Stock 99 - Hellinger Distance PSMF: 0.046357025549050274
# Stock 99 - Hellinger Distance Mean: 0.12949728205336203
#
# ================================================================================
#
# Stock 100 - KS Statistic PSMF: 0.022638567869072618, P-value PSMF: 0.9261091902100165
# ...
# Stock 485 - Hellinger Distance PSMF: 0.37274829199140835
# Stock 485 - Hellinger Distance Mean: 0.5747761046147906
#
# ================================================================================
#
# Stock 486 - KS Statistic PSMF: 0.03284613783701413, P-value PSMF: 0.5628953149863417
# Stock 486 - KS Statistic Mean: 0.10943775961263398, P-value Mean: 2.464478324413257e-06
# Stock 486 - Wasserstein Distance PSMF: 0.5072978727096593
# Stock 486 - Wasserstein Distance Mean: 1.736596070544514
# Stock 486 - Hellinger Distance PSMF: 0.0822564852045493
# Stock 486 - Hellinger Distance Mean: 0.1998374277974834
#
# ================================================================================
#
# Stock 487 - KS Statistic PSMF: 0.04358388831184701, P-value PSMF: 0.22089834082367704
# Stock 487 - KS Statistic Mean: 0.09667471130934197, P-value Mean: 4.3211949329195865e-05
# Stock 487 - Wasserstein Distance PSMF: 0.7247713253962127
# Stock 487 - Wasserstein Distance Mean: 1.0951349894957487
# Stock 487 - Hellinger Distance PSMF: 0.05726428552717393
# Stock 487 - Hellinger Distance Mean: 0.15786634348527723
#
# ================================================================================
#
# Stock 488 - KS Statistic PSMF: 0.07433929367093513, P-value PSMF: 0.0036258759059063527
# Stock 488 - KS Statistic Mean: 0.10408260524225575, P-value Mean: 8.66474119909449e-06
# Stock 488 - Wasserstein Distance PSMF: 1.4796578386449486
# Stock 488 - Wasserstein Distance Mean: 2.300474648792111
# Stock 488 - Hellinger Distance PSMF: 0.08061219989904916
# Stock 488 - Hellinger Distance Mean: 0.22919760295524838
#
# ================================================================================
#
# Stock 489 - KS Statistic PSMF: 0.3747488204449873, P-value PSMF: 1.820237850898813e-45
# Stock 489 - KS Statistic Mean: 0.33177694306174826, P-value Mean: 1.5546035658539236e-35
# Stock 489 - Wasserstein Distance PSMF: 10.650728806939856
# Stock 489 - Wasserstein Distance Mean: 4.538120347106963
# Stock 489 - Hellinger Distance PSMF: 0.36387624379056194
# Stock 489 - Hellinger Distance Mean: 0.5484515859916669
#
# ================================================================================
#
# Stock 490 - KS Statistic PSMF: 0.03186188571414941, P-value PSMF: 0.6086202669041921
# Stock 490 - KS Statistic Mean: 0.11969077894415464, P-value Mean: 2.0471699001431518e-07
# Stock 490 - Wasserstein Distance PSMF: 0.10357877476777166
# Stock 490 - Wasserstein Distance Mean: 0.28783791412218085
# Stock 490 - Hellinger Distance PSMF: 0.17981549635982716
# Stock 490 - Hellinger Distance Mean: 0.5335874595020254
#
# ================================================================================
#
# Stock 491 - KS Statistic PSMF: 0.0406092749990877, P-value PSMF: 0.2989415918061809
# Stock 491 - KS Statistic Mean: 0.09619886378194303, P-value Mean: 5.275413801365182e-05
# Stock 491 - Wasserstein Distance PSMF: 3.511523799014402
# Stock 491 - Wasserstein Distance Mean: 7.584728401560427
# Stock 491 - Hellinger Distance PSMF: 0.03675838888451259
# Stock 491 - Hellinger Distance Mean: 0.11141176249757889
#
# ================================================================================
#
# Stock 492 - KS Statistic PSMF: 0.046330549444569984, P-value PSMF: 0.16410395348066312
# Stock 492 - KS Statistic Mean: 0.0993463617614451, P-value Mean: 2.2215299086225766e-05
# Stock 492 - Wasserstein Distance PSMF: 1.1851549217156763
# Stock 492 - Wasserstein Distance Mean: 1.8649736713106497
# Stock 492 - Hellinger Distance PSMF: 0.0827468282545993
# Stock 492 - Hellinger Distance Mean: 0.16724276210373376
#
# ================================================================================
#
# Stock 493 - KS Statistic PSMF: 0.026621002052548384, P-value PSMF: 0.8084432194778636
# Stock 493 - KS Statistic Mean: 0.10260854520718156, P-value Mean: 1.3500214998667869e-05
# Stock 493 - Wasserstein Distance PSMF: 0.12737124898780466
# Stock 493 - Wasserstein Distance Mean: 0.39293484057030337
# Stock 493 - Hellinger Distance PSMF: 0.09071085779738243
# Stock 493 - Hellinger Distance Mean: 0.3430609023513417
#
# ================================================================================
#
# Stock 494 - KS Statistic PSMF: 0.02814091482502453, P-value PSMF: 0.7490445345134915
# Stock 494 - KS Statistic Mean: 0.10738603622545126, P-value Mean: 4.05362068800066e-06
# Stock 494 - Wasserstein Distance PSMF: 0.9760525749932294
# Stock 494 - Wasserstein Distance Mean: 2.9162718606731266
# Stock 494 - Hellinger Distance PSMF: 0.05587636307901982
# Stock 494 - Hellinger Distance Mean: 0.17306511455742205
#
# ================================================================================
#
# Stock 495 - KS Statistic PSMF: 0.08420622738181477, P-value PSMF: 0.0006187860176665277
# Stock 495 - KS Statistic Mean: 0.10059652612626042, P-value Mean: 1.974367349877294e-05
# Stock 495 - Wasserstein Distance PSMF: 0.9611268175863623
# Stock 495 - Wasserstein Distance Mean: 1.0794070499298125
# Stock 495 - Hellinger Distance PSMF: 0.15714500390392241
# Stock 495 - Hellinger Distance Mean: 0.35958136557052134
#
# ================================================================================
#
# Stock 496 - KS Statistic PSMF: 0.05403656237651472, P-value PSMF: 0.07376313458226955
# Stock 496 - KS Statistic Mean: 0.14036276149064075, P-value Mean: 4.884490920107047e-10
# Stock 496 - Wasserstein Distance PSMF: 0.5631853781342966
# Stock 496 - Wasserstein Distance Mean: 1.4754495957832723
# Stock 496 - Hellinger Distance PSMF: 0.14214044018620436
# Stock 496 - Hellinger Distance Mean: 0.2935283835166325
#
# ================================================================================
#
# Stock 497 - KS Statistic PSMF: 0.04017304593994737, P-value PSMF: 0.31181485202202625
# Stock 497 - KS Statistic Mean: 0.10146261316172918, P-value Mean: 1.6397920689026556e-05
# Stock 497 - Wasserstein Distance PSMF: 0.17204173745864648
# Stock 497 - Wasserstein Distance Mean: 0.5708186065656113
# Stock 497 - Hellinger Distance PSMF: 0.13731422706795043
# Stock 497 - Hellinger Distance Mean: 0.3434656771993796
#
# ================================================================================
#
# Stock 498 - KS Statistic PSMF: 0.03418802100603808, P-value PSMF: 0.5077192674273825
# Stock 498 - KS Statistic Mean: 0.09641956553590846, P-value Mean: 4.842498700017011e-05
# Stock 498 - Wasserstein Distance PSMF: 0.40172567321037506
# Stock 498 - Wasserstein Distance Mean: 1.0309492876063766
# Stock 498 - Hellinger Distance PSMF: 0.07739749862360883
# Stock 498 - Hellinger Distance Mean: 0.23415986117295456
#
# ================================================================================
#
# Stock 499 - KS Statistic PSMF: 0.04488035321244749, P-value PSMF: 0.1958666687642542
# Stock 499 - KS Statistic Mean: 0.09608105828144055, P-value Mean: 5.181172914988665e-05
# Stock 499 - Wasserstein Distance PSMF: 0.5857646758662746
# Stock 499 - Wasserstein Distance Mean: 1.2468467028812742
# Stock 499 - Hellinger Distance PSMF: 0.10898623758218252
# Stock 499 - Hellinger Distance Mean: 0.3402325379188357
#
# ================================================================================
#
# Stock 500 - KS Statistic PSMF: 0.08032620577387366, P-value PSMF: 0.0013418747897161584
# Stock 500 - KS Statistic Mean: 0.09986709552607366, P-value Mean: 2.5256880592999453e-05
# Stock 500 - Wasserstein Distance PSMF: 1.1940791847443193
# Stock 500 - Wasserstein Distance Mean: 1.1830298401650263
# Stock 500 - Hellinger Distance PSMF: 0.15288205718760564
# Stock 500 - Hellinger Distance Mean: 0.25526494013347834
#
# ================================================================================
#
# Stock 501 - KS Statistic PSMF: 0.04779301079242189, P-value PSMF: 0.14594471467801845
# Stock 501 - KS Statistic Mean: 0.11701527649308913, P-value Mean: 3.458523701393188e-07
# Stock 501 - Wasserstein Distance PSMF: 0.9394035424116234
# Stock 501 - Wasserstein Distance Mean: 1.8783143365712078
# Stock 501 - Hellinger Distance PSMF: 0.08213776154805624
# Stock 501 - Hellinger Distance Mean: 0.23810610785187167
#
# ================================================================================
#
# Stock 502 - KS Statistic PSMF: 0.025441940696270465, P-value PSMF: 0.8469101376323317
# Stock 502 - KS Statistic Mean: 0.10438678609205088, P-value Mean: 8.390531107325712e-06
# Stock 502 - Wasserstein Distance PSMF: 0.23569451558219476
# Stock 502 - Wasserstein Distance Mean: 1.1833335837610925
# Stock 502 - Hellinger Distance PSMF: 0.1701882256797358
# Stock 502 - Hellinger Distance Mean: 0.25043321071930524
#
# ================================================================================
#
# Stock 503 - KS Statistic PSMF: 0.04439425568392894, P-value PSMF: 0.20802404387627751
# Stock 503 - KS Statistic Mean: 0.09946389906567042, P-value Mean: 2.5717229073695232e-05
# Stock 503 - Wasserstein Distance PSMF: 0.7815731394117786
# Stock 503 - Wasserstein Distance Mean: 2.324976642756731
# Stock 503 - Hellinger Distance PSMF: 0.07147856377283314
# Stock 503 - Hellinger Distance Mean: 0.21419815363644637
#
# ================================================================================
#
# Stock 504 - KS Statistic PSMF: 0.07545035106591898, P-value PSMF: 0.0032878554173512427
# Stock 504 - KS Statistic Mean: 0.15379955014585675, P-value Mean: 5.729531309197352e-12
# Stock 504 - Wasserstein Distance PSMF: 0.51336185364888
# Stock 504 - Wasserstein Distance Mean: 1.341247132684639
# Stock 504 - Hellinger Distance PSMF: 0.1530592027322655
# Stock 504 - Hellinger Distance Mean: 0.31355454882666234
#
# ================================================================================
#
# Stock 505 - KS Statistic PSMF: 0.04468701686706734, P-value PSMF: 0.20073716463474342
# Stock 505 - KS Statistic Mean: 0.09796804777752084, P-value Mean: 3.49261469060289e-05
# Stock 505 - Wasserstein Distance PSMF: 0.8566784535418206
# Stock 505 - Wasserstein Distance Mean: 1.786994445102922
# Stock 505 - Hellinger Distance PSMF: 0.12203165918882727
# Stock 505 - Hellinger Distance Mean: 0.21770484425535844
#
# ================================================================================
# Error in callback <function _draw_all_if_interactive at 0x144526340> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/patches.py:588, in Patch.draw(self, renderer)
#     586 tpath = transform.transform_path_non_affine(path)
#     587 affine = transform.get_affine()
# --> 588 self._draw_paths_with_artist_properties(
#     589     renderer,
#     590     [(tpath, affine,
#     591       # Work around a bug in the PDF and SVG renderers, which
#     592       # do not draw the hatches if the facecolor is fully
#     593       # transparent, but do if it is None.
#     594       self._facecolor if self._facecolor[3] else None)])
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/patches.py:573, in Patch._draw_paths_with_artist_properties(self, renderer, draw_path_args_list)
#     570     renderer = PathEffectRenderer(self.get_path_effects(), renderer)
#     572 for draw_path_args in draw_path_args_list:
# --> 573     renderer.draw_path(gc, *draw_path_args)
#     575 gc.restore()
#     576 renderer.close_group('patch')
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:132, in RendererAgg.draw_path(self, gc, path, transform, rgbFace)
#     130 else:
#     131     try:
# --> 132         self._renderer.draw_path(gc, path, transform, rgbFace)
#     133     except OverflowError:
#     134         cant_chunk = ''
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/backend_bases.py:849, in GraphicsContextBase.get_dashes(self)
#     846             return None, None
#     847     return None, None
# --> 849 def get_dashes(self):
#     850     """
#     851     Return the dash style as an (offset, dash-list) pair.
#     852
#    (...)
#     855     Default value is (None, None).
#     856     """
#     857     return self._dashes
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
from scipy.stats import ks_2samp, wasserstein_distance

def hellinger(p, q):
    """Calculate the Hellinger distance between two probability distributions."""
    return np.sqrt(np.sum((np.sqrt(p) - np.sqrt(q))**2)) / np.sqrt(2)

# Load the original dataset
original_path = '/Users/guillermodominguez/Documents/Imperial College London/Dissertation/rPSMF/ExperimentImpute/data/sp500_closing_prices_masked_0percent.csv'
df_original = pd.read_csv(original_path, header=None)

# Load the imputed dataset from PSMF
psmf_path = '/Users/guillermodominguez/Documents/Imperial College London/Dissertation/rPSMF/Y_imputed_0_PSMF.csv'
df_imputed = pd.read_csv(psmf_path, header=None)

# Only replace missing values in the original dataset with values from the imputed dataset
df_final = df_original.copy()
mask = df_original.isna()  # Create a boolean mask for where NaN values are in the original dataframe
df_final[mask] = df_imputed[mask]  # Replace only the NaN values

# Impute missing values with the mean of each row
df_mean_imputed = df_original.copy()

# Apply row-wise mean imputation
for index, row in df_mean_imputed.iterrows():
    # Calculate the mean of the current row excluding NaNs
    row_mean = row.mean()
    # Fill NaNs in this row with the calculated mean
    df_mean_imputed.iloc[index] = row.fillna(row_mean)

# Find rows that contain at least one NaN
rows_with_nan = mask.any(axis=1)

# Get indices of these rows
rows_with_nan_indices = rows_with_nan[rows_with_nan].index.tolist()

# Initialize lists to store results
ks_stats_psmf = []
ks_pvalues_psmf = []
ks_stats_mean = []
ks_pvalues_mean = []
wasserstein_psmf_list = []
wasserstein_mean_list = []
hellinger_psmf_list = []
hellinger_mean_list = []

for idx, stock_row in enumerate(rows_with_nan_indices, start=1):
    
    # Drop NA values for the original for a fair comparison
    original_clean = df_original.iloc[stock_row].dropna()

    # Normalize the data for Hellinger distance calculation
    original_hist, _ = np.histogram(original_clean, bins=50, density=True)
    psmf_hist, _ = np.histogram(df_final.iloc[stock_row].dropna(), bins=50, density=True)
    mean_hist, _ = np.histogram(df_mean_imputed.iloc[stock_row].dropna(), bins=50, density=True)
    
    # Calculate the Hellinger distance
    hellinger_psmf = hellinger(original_hist, psmf_hist)
    hellinger_mean = hellinger(original_hist, mean_hist)
    
    # Append Hellinger distances to lists
    hellinger_psmf_list.append(hellinger_psmf)
    hellinger_mean_list.append(hellinger_mean)

    # KS Test between original and PSMF imputed
    ks_stat_psmf, ks_pvalue_psmf = ks_2samp(original_clean, df_final.iloc[stock_row].dropna())
    ks_stats_psmf.append(ks_stat_psmf)
    ks_pvalues_psmf.append(ks_pvalue_psmf)

    # KS Test between original and Mean imputed
    ks_stat_mean, ks_pvalue_mean = ks_2samp(original_clean, df_mean_imputed.iloc[stock_row].dropna())
    ks_stats_mean.append(ks_stat_mean)
    ks_pvalues_mean.append(ks_pvalue_mean)

    # Wasserstein Distance between original and PSMF imputed
    wasserstein_psmf = wasserstein_distance(original_clean, df_final.iloc[stock_row].dropna())
    wasserstein_psmf_list.append(wasserstein_psmf)

    # Wasserstein Distance between original and Mean imputed
    wasserstein_mean = wasserstein_distance(original_clean, df_mean_imputed.iloc[stock_row].dropna())
    wasserstein_mean_list.append(wasserstein_mean)
    
    # Print KS, Wasserstein, and Hellinger results for this stock
    print(f"Stock {idx} - KS Statistic PSMF: {ks_stat_psmf}, P-value PSMF: {ks_pvalue_psmf}")
    print(f"Stock {idx} - KS Statistic Mean: {ks_stat_mean}, P-value Mean: {ks_pvalue_mean}")
    print(f"Stock {idx} - Wasserstein Distance PSMF: {wasserstein_psmf}")
    print(f"Stock {idx} - Wasserstein Distance Mean: {wasserstein_mean}")
    print(f"Stock {idx} - Hellinger Distance PSMF: {hellinger_psmf}")
    print(f"Stock {idx} - Hellinger Distance Mean: {hellinger_mean}")
# Out:
# Stock 1 - KS Statistic PSMF: 0.1556791104050834, P-value PSMF: 1.1575335509452793e-12
# Stock 1 - KS Statistic Mean: 0.08186700161471461, P-value Mean: 0.0008168855377024989
# Stock 1 - Wasserstein Distance PSMF: 5.524835336394652
# Stock 1 - Wasserstein Distance Mean: 1.413084662895336
# Stock 1 - Hellinger Distance PSMF: 0.342301304078365
# Stock 1 - Hellinger Distance Mean: 0.1761931487459466
# Stock 2 - KS Statistic PSMF: 0.9650516282764099, P-value PSMF: 2.547142761140573e-57
# Stock 2 - KS Statistic Mean: 0.5044588056899415, P-value Mean: 1.5901663749380204e-10
# Stock 2 - Wasserstein Distance PSMF: 52.21255989350877
# Stock 2 - Wasserstein Distance Mean: 3.7290970713343268
# Stock 2 - Hellinger Distance PSMF: 1.2173987570534823
# Stock 2 - Hellinger Distance Mean: 1.770414754750674
# Stock 3 - KS Statistic PSMF: 0.39537983858873454, P-value PSMF: 1.4906780115091178e-18
# Stock 3 - KS Statistic Mean: 0.5020967912151391, P-value Mean: 2.652383191858639e-30
# Stock 3 - Wasserstein Distance PSMF: 9.47380230560278
# Stock 3 - Wasserstein Distance Mean: 2.742096181860985
# Stock 3 - Hellinger Distance PSMF: 0.7167256118060438
# Stock 3 - Hellinger Distance Mean: 1.2303294751681841
# Stock 4 - KS Statistic PSMF: 0.8663360645457966, P-value PSMF: 1.0874281438136556e-112
# Stock 4 - KS Statistic Mean: 0.44541929685213827, P-value Mean: 6.204006559200715e-25
# Stock 4 - Wasserstein Distance PSMF: 38.36724556326503
# Stock 4 - Wasserstein Distance Mean: 1.9581155954138505
# Stock 4 - Hellinger Distance PSMF: 0.7756222059897646
# Stock 4 - Hellinger Distance Mean: 0.8478611620977592
# Stock 5 - KS Statistic PSMF: 0.0014356458479062128, P-value PSMF: 1.0
# Stock 5 - KS Statistic Mean: 0.0008050232439403677, P-value Mean: 1.0
# Stock 5 - Wasserstein Distance PSMF: 0.020732834686565338
# Stock 5 - Wasserstein Distance Mean: 0.011288686716214281
# Stock 5 - Hellinger Distance PSMF: 0.004186475634717612
# Stock 5 - Hellinger Distance Mean: 0.0034855036950297894
# Stock 6 - KS Statistic PSMF: 0.21311965612297343, P-value PSMF: 1.1360548802684624e-20
# Stock 6 - KS Statistic Mean: 0.20561790403214503, P-value Mean: 2.9117113464442813e-19
# Stock 6 - Wasserstein Distance PSMF: 4.561834089673553
# Stock 6 - Wasserstein Distance Mean: 1.9411798917029222
# Stock 6 - Hellinger Distance PSMF: 0.4294810071540841
# Stock 6 - Hellinger Distance Mean: 0.49763417883970973
# Stock 7 - KS Statistic PSMF: 0.05027671185198879, P-value PSMF: 0.08868757807653697
# Stock 7 - KS Statistic Mean: 0.04216123027585866, P-value Mean: 0.22197851624607715
# Stock 7 - Wasserstein Distance PSMF: 0.46545400087515776
# Stock 7 - Wasserstein Distance Mean: 0.28984841791440524
# Stock 7 - Hellinger Distance PSMF: 0.09346111508312953
# Stock 7 - Hellinger Distance Mean: 0.2158341288121306
# Stock 8 - KS Statistic PSMF: 0.4958438281804165, P-value PSMF: 1.999603666785224e-87
# Stock 8 - KS Statistic Mean: 0.2944985055904086, P-value Mean: 3.29225602557043e-30
# Stock 8 - Wasserstein Distance PSMF: 6.767743675087283
# Stock 8 - Wasserstein Distance Mean: 1.4145332145478908
# Stock 8 - Hellinger Distance PSMF: 0.6489811340406112
# Stock 8 - Hellinger Distance Mean: 0.9858900230373847
# Stock 9 - KS Statistic PSMF: 0.002991174724605527, P-value PSMF: 1.0
# Stock 9 - KS Statistic Mean: 0.006625186828607158, P-value Mean: 0.9999999999999963
# Stock 9 - Wasserstein Distance PSMF: 0.04164489913109231
# Stock 9 - Wasserstein Distance Mean: 0.09713761322028465
# Stock 9 - Hellinger Distance PSMF: 0.008558337900933258
# Stock 9 - Hellinger Distance Mean: 0.02074738650252727
# Stock 10 - KS Statistic PSMF: 0.7790295195691935, P-value PSMF: 1.7353946917818835e-63
# Stock 10 - KS Statistic Mean: 0.5447019988195088, P-value Mean: 2.9134626461168744e-28
# Stock 10 - Wasserstein Distance PSMF: 16.81248401406971
# Stock 10 - Wasserstein Distance Mean: 1.5819160875130591
# Stock 10 - Hellinger Distance PSMF: 0.9815269573472183
# Stock 10 - Hellinger Distance Mean: 1.3205672626385705
# Stock 11 - KS Statistic PSMF: 0.5409054805401112, P-value PSMF: 2.5757599172892317e-50
# Stock 11 - KS Statistic Mean: 0.5013946099709995, P-value Mean: 7.020393840670315e-43
# Stock 11 - Wasserstein Distance PSMF: 28.191083636336543
# Stock 11 - Wasserstein Distance Mean: 6.404231730781211
# Stock 11 - Hellinger Distance PSMF: 0.5824190970231826
# Stock 11 - Hellinger Distance Mean: 0.9214882746455358
# Stock 12 - KS Statistic PSMF: 0.0036375406918068213, P-value PSMF: 1.0
# Stock 12 - KS Statistic Mean: 0.0041399283048360845, P-value Mean: 0.9999999999999997
# Stock 12 - Wasserstein Distance PSMF: 0.04398006187936775
# Stock 12 - Wasserstein Distance Mean: 0.04786906739824247
# Stock 12 - Hellinger Distance PSMF: 0.011423027157212688
# Stock 12 - Hellinger Distance Mean: 0.023046755818585517
# Stock 13 - KS Statistic PSMF: 0.24066719618745036, P-value PSMF: 1.0134703994860023e-12
# Stock 13 - KS Statistic Mean: 0.44765366131529755, P-value Mean: 4.161193016784169e-44
# Stock 13 - Wasserstein Distance PSMF: 7.030289812174063
# Stock 13 - Wasserstein Distance Mean: 8.66586283672026
# Stock 13 - Hellinger Distance PSMF: 0.3865745939987908
# Stock 13 - Hellinger Distance Mean: 0.6836369531513677
# Stock 14 - KS Statistic PSMF: 0.03889395836716446, P-value PSMF: 0.30737195017408897
# Stock 14 - KS Statistic Mean: 0.0358955299431773, P-value Mean: 0.40268952829441107
# Stock 14 - Wasserstein Distance PSMF: 0.20572548530784684
# Stock 14 - Wasserstein Distance Mean: 0.2159115721722987
# Stock 14 - Hellinger Distance PSMF: 0.07712180978774702
# Stock 14 - Hellinger Distance Mean: 0.20574908352585386
# Stock 15 - KS Statistic PSMF: 0.06219241988053848, P-value PSMF: 0.01733799487898125
# Stock 15 - KS Statistic Mean: 0.03620128403127932, P-value Mean: 0.39221480249103186
# Stock 15 - Wasserstein Distance PSMF: 0.34773455314067236
# Stock 15 - Wasserstein Distance Mean: 0.1929197750520123
# Stock 15 - Hellinger Distance PSMF: 0.16266682585402045
# Stock 15 - Hellinger Distance Mean: 0.21242196348987402
# Stock 16 - KS Statistic PSMF: 0.6791104050833995, P-value PSMF: 3.297941504824208e-136
# Stock 16 - KS Statistic Mean: 0.34123616889091607, P-value Mean: 3.8157076734928466e-32
# Stock 16 - Wasserstein Distance PSMF: 38.87928875975041
# Stock 16 - Wasserstein Distance Mean: 4.944857600708678
# Stock 16 - Hellinger Distance PSMF: 0.6024114740245698
# Stock 16 - Hellinger Distance Mean: 0.7834106577707961
# Stock 17 - KS Statistic PSMF: 0.22398729150119143, P-value PSMF: 1.1940224292356612e-24
# Stock 17 - KS Statistic Mean: 0.11544856520233804, P-value Mean: 7.674264943471248e-07
# Stock 17 - Wasserstein Distance PSMF: 152.1471387199988
# Stock 17 - Wasserstein Distance Mean: 30.978738789314797
# Stock 17 - Hellinger Distance PSMF: 0.13143089160575205
# Stock 17 - Hellinger Distance Mean: 0.06345002092046904
# Stock 18 - KS Statistic PSMF: 0.31488356298419495, P-value PSMF: 2.1659971121394473e-20
# Stock 18 - KS Statistic Mean: 0.4695986002233196, P-value Mean: 6.371324219506661e-46
# Stock 18 - Wasserstein Distance PSMF: 4.946252211307808
# Stock 18 - Wasserstein Distance Mean: 5.472071691675427
# Stock 18 - Hellinger Distance PSMF: 0.4942835429725437
# Stock 18 - Hellinger Distance Mean: 0.7894108662698026
# Stock 19 - KS Statistic PSMF: 0.5385226370135028, P-value PSMF: 1.6188029651670767e-106
# Stock 19 - KS Statistic Mean: 0.307727221150573, P-value Mean: 9.081156005410254e-34
# Stock 19 - Wasserstein Distance PSMF: 27.330656324186016
# Stock 19 - Wasserstein Distance Mean: 1.617072119832363
# Stock 19 - Hellinger Distance PSMF: 1.076163665995501
# Stock 19 - Hellinger Distance Mean: 0.9218231659349501
# Stock 20 - KS Statistic PSMF: 0.5215747820511594, P-value PSMF: 1.4421508892381932e-99
# Stock 20 - KS Statistic Mean: 0.3040196642692408, P-value Mean: 5.876373230659287e-33
# Stock 20 - Wasserstein Distance PSMF: 12.009697042322685
# Stock 20 - Wasserstein Distance Mean: 1.667914083455546
# Stock 20 - Hellinger Distance PSMF: 0.7708239990320321
# Stock 20 - Hellinger Distance Mean: 0.8633334216481499
# Stock 21 - KS Statistic PSMF: 0.003075147613419425, P-value PSMF: 1.0
# Stock 21 - KS Statistic Mean: 0.0023087359528143774, P-value Mean: 1.0
# Stock 21 - Wasserstein Distance PSMF: 0.04771178549154753
# Stock 21 - Wasserstein Distance Mean: 0.03471678408563647
# Stock 21 - Hellinger Distance PSMF: 0.005593478447175731
# Stock 21 - Hellinger Distance Mean: 0.010200487019972396
# Stock 22 - KS Statistic PSMF: 0.12616857643505475, P-value PSMF: 7.972797840629912e-08
# Stock 22 - KS Statistic Mean: 0.14011743581437208, P-value Mean: 1.496816474723797e-09
# Stock 22 - Wasserstein Distance PSMF: 1.5077674127350358
# Stock 22 - Wasserstein Distance Mean: 1.836315191124871
# Stock 22 - Hellinger Distance PSMF: 0.6936958005838225
# Stock 22 - Hellinger Distance Mean: 0.4252455052341753
# Stock 23 - KS Statistic PSMF: 0.048451151707704525, P-value PSMF: 0.10725686328056315
# Stock 23 - KS Statistic Mean: 0.02563066389829485, P-value Mean: 0.8012226121687381
# Stock 23 - Wasserstein Distance PSMF: 1.5664361165696437
# Stock 23 - Wasserstein Distance Mean: 0.6663369553264291
# Stock 23 - Hellinger Distance PSMF: 0.25456113464195196
# Stock 23 - Hellinger Distance Mean: 0.060125671838897034
# Stock 24 - KS Statistic PSMF: 0.4797458300238284, P-value PSMF: 1.7713542224598647e-90
# Stock 24 - KS Statistic Mean: 0.2446337514930667, P-value Mean: 3.8857656018633437e-23
# Stock 24 - Wasserstein Distance PSMF: 19.175263846983917
# Stock 24 - Wasserstein Distance Mean: 2.7625904277940743
# Stock 24 - Hellinger Distance PSMF: 0.6568924862436911
# Stock 24 - Hellinger Distance Mean: 0.6249295137267696
# Stock 25 - KS Statistic PSMF: 0.22239872915011913, P-value PSMF: 4.259781381450903e-24
# Stock 25 - KS Statistic Mean: 0.13012476833465714, P-value Mean: 1.667229348696696e-08
# Stock 25 - Wasserstein Distance PSMF: 3.337243058612526
# Stock 25 - Wasserstein Distance Mean: 0.6042974100159407
# Stock 25 - Hellinger Distance PSMF: 0.6431246736335027
# Stock 25 - Hellinger Distance Mean: 0.50182684474139
# Stock 26 - KS Statistic PSMF: 0.07148530579825259, P-value PSMF: 0.0038098789683829446
# Stock 26 - KS Statistic Mean: 0.03607898239603852, P-value Mean: 0.39638468892932344
# Stock 26 - Wasserstein Distance PSMF: 0.6089277408652354
# Stock 26 - Wasserstein Distance Mean: 0.1265744280466411
# Stock 26 - Hellinger Distance PSMF: 1.0900186627322836
# Stock 26 - Hellinger Distance Mean: 0.285835761876356
# Stock 27 - KS Statistic PSMF: 0.07148530579825259, P-value PSMF: 0.0038098789683829446
# Stock 27 - KS Statistic Mean: 0.038341562647993474, P-value Mean: 0.3236933264422643
# Stock 27 - Wasserstein Distance PSMF: 0.8373585862782409
# Stock 27 - Wasserstein Distance Mean: 0.11061799577170547
# Stock 27 - Hellinger Distance PSMF: 1.3825014524757688
# Stock 27 - Hellinger Distance Mean: 0.3004638821795484
# Stock 28 - KS Statistic PSMF: 0.001400260210809933, P-value PSMF: 1.0
# Stock 28 - KS Statistic Mean: 0.0008505190630641561, P-value Mean: 1.0
# Stock 28 - Wasserstein Distance PSMF: 0.0106421801886805
# Stock 28 - Wasserstein Distance Mean: 0.006030787680938724
# Stock 28 - Hellinger Distance PSMF: 0.004024749162064842
# Stock 28 - Hellinger Distance Mean: 0.003279845041119812
# Stock 29 - KS Statistic PSMF: 0.0061855525174495845, P-value PSMF: 0.9999999999999986
# Stock 29 - KS Statistic Mean: 0.0067683235810770655, P-value Mean: 0.999999999999996
# Stock 29 - Wasserstein Distance PSMF: 0.059623516810947325
# Stock 29 - Wasserstein Distance Mean: 0.08930589706604566
# Stock 29 - Hellinger Distance PSMF: 0.013720379008648984
# Stock 29 - Hellinger Distance Mean: 0.03341414673664183
# Stock 30 - KS Statistic PSMF: 0.3890898507842769, P-value PSMF: 8.973753965053637e-59
# Stock 30 - KS Statistic Mean: 0.33472342644410624, P-value Mean: 2.6505326317688298e-43
# Stock 30 - Wasserstein Distance PSMF: 7.855845358797238
# Stock 30 - Wasserstein Distance Mean: 5.331193380191033
# Stock 30 - Hellinger Distance PSMF: 0.3926058273852064
# Stock 30 - Hellinger Distance Mean: 0.504190331732699
# Stock 31 - KS Statistic PSMF: 0.16188996205553052, P-value PSMF: 1.6790006122856216e-11
# Stock 31 - KS Statistic Mean: 0.19979883634248266, P-value Mean: 2.55607630960101e-17
# Stock 31 - Wasserstein Distance PSMF: 4.548718176723904
# Stock 31 - Wasserstein Distance Mean: 3.8431822705408476
# Stock 31 - Hellinger Distance PSMF: 0.2872805527651013
# Stock 31 - Hellinger Distance Mean: 0.4145873091101527
# Stock 32 - KS Statistic PSMF: 0.16407541377755833, P-value PSMF: 1.0312937658574008e-12
# Stock 32 - KS Statistic Mean: 0.15497159192552362, P-value Mean: 2.1957898615748985e-11
# Stock 32 - Wasserstein Distance PSMF: 1.1581982044877237
# Stock 32 - Wasserstein Distance Mean: 0.8467325676462962
# Stock 32 - Hellinger Distance PSMF: 0.29942289725792487
# Stock 32 - Hellinger Distance Mean: 0.4756788090553693
# Stock 33 - KS Statistic PSMF: 0.5682653857741503, P-value PSMF: 4.456574119028578e-102
# Stock 33 - KS Statistic Mean: 0.3511099394702966, P-value Mean: 1.1220744004294266e-37
# Stock 33 - Wasserstein Distance PSMF: 29.240084588126315
# Stock 33 - Wasserstein Distance Mean: 5.181416825757046
# Stock 33 - Hellinger Distance PSMF: 0.5581299673269347
# Stock 33 - Hellinger Distance Mean: 0.6881679097307202
# Stock 34 - KS Statistic PSMF: 0.5806195393169182, P-value PSMF: 4.3083257001295634e-117
# Stock 34 - KS Statistic Mean: 0.36728584494668687, P-value Mean: 3.1880707747918e-45
# Stock 34 - Wasserstein Distance PSMF: 48.27328879470605
# Stock 34 - Wasserstein Distance Mean: 7.716849464958814
# Stock 34 - Hellinger Distance PSMF: 0.4489007567658506
# Stock 34 - Hellinger Distance Mean: 0.5201985618795134
# Stock 35 - KS Statistic PSMF: 0.3126444283935123, P-value PSMF: 5.296298707790125e-38
# Stock 35 - KS Statistic Mean: 0.27290757302707513, P-value Mean: 5.971870916896547e-29
# Stock 35 - Wasserstein Distance PSMF: 4.491478116555052
# Stock 35 - Wasserstein Distance Mean: 3.3921807780214683
# Stock 35 - Hellinger Distance PSMF: 0.2831938941682442
# Stock 35 - Hellinger Distance Mean: 0.43363435435130865

# %%
# Calculate overall means for the Wasserstein distances, KS statistics, and Hellinger distances
mean_wasserstein_psmf = np.mean(wasserstein_psmf_list)
mean_wasserstein_mean = np.mean(wasserstein_mean_list)

mean_ks_stat_psmf = np.mean(ks_stats_psmf)
mean_ks_stat_mean = np.mean(ks_stats_mean)

mean_hellinger_psmf = np.mean(hellinger_psmf_list)
mean_hellinger_mean = np.mean(hellinger_mean_list)

# Print the overall means
print(f"Overall Mean Wasserstein Distance for PSMF Imputation: {mean_wasserstein_psmf}")
print(f"Overall Mean Wasserstein Distance for Mean Imputation: {mean_wasserstein_mean}")

print(f"Overall Mean KS Statistic for PSMF Imputation: {mean_ks_stat_psmf}")
print(f"Overall Mean KS Statistic for Mean Imputation: {mean_ks_stat_mean}")

print(f"Overall Mean Hellinger Distance for PSMF Imputation: {mean_hellinger_psmf}")
print(f"Overall Mean Hellinger Distance for Mean Imputation: {mean_hellinger_mean}")
# Out:
# Overall Mean Wasserstein Distance for PSMF Imputation: 15.088536305789454
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0838310815502257
# Overall Mean KS Statistic for PSMF Imputation: 0.2941856826220132
# Overall Mean KS Statistic for Mean Imputation: 0.21420625522291223
# Overall Mean Hellinger Distance for PSMF Imputation: 0.47220652988965356
# Overall Mean Hellinger Distance for Mean Imputation: 0.5091002034776553

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr, spearmanr

# Paths to the CSV files
original_path = '/Users/guillermodominguez/Documents/Imperial College London/Dissertation/rPSMF/ExperimentImpute/data/cleaned_sp500_stocks_matrix.csv'
psmf_path = '/Users/guillermodominguez/Documents/Imperial College London/Dissertation/rPSMF/Y_imputed_CLEANED_PSMF.csv'
masked_path = '/Users/guillermodominguez/Documents/Imperial College London/Dissertation/rPSMF/ExperimentImpute/data/cleaned_sp500_stocks_matrix_masked_20percent.csv'

# Load the datasets
df_original = pd.read_csv(original_path, header=None)
df_psmf = pd.read_csv(psmf_path, header=None)
df_masked = pd.read_csv(masked_path, header=None)

# Convert all data to numeric, setting errors='coerce' to handle non-numeric values
df_original = df_original.apply(pd.to_numeric, errors='coerce')
df_psmf = df_psmf.apply(pd.to_numeric, errors='coerce')
df_masked = df_masked.apply(pd.to_numeric, errors='coerce')

# Create a mask of the missing values
mask = df_masked.isna()

# Impute missing values using mean imputation
df_mean_imputed = df_masked.copy()
for index, row in df_mean_imputed.iterrows():
    row_mean = row.mean()
    df_mean_imputed.iloc[index] = row.fillna(row_mean)

# Extract only the values that were originally missing
original_missing_values = df_original[mask].values
psmf_imputed_values = df_psmf[mask].values
mean_imputed_values = df_mean_imputed[mask].values

# Ensure no NaN values are present in the extracted values
original_missing_values = original_missing_values[~np.isnan(original_missing_values)]
psmf_imputed_values = psmf_imputed_values[~np.isnan(psmf_imputed_values)]
mean_imputed_values = mean_imputed_values[~np.isnan(mean_imputed_values)]

# Calculate metrics for PSMF Imputation
rmse_psmf = np.sqrt(mean_squared_error(original_missing_values, psmf_imputed_values))
mae_psmf = mean_absolute_error(original_missing_values, psmf_imputed_values)
mape_psmf = np.mean(np.abs((original_missing_values - psmf_imputed_values) / original_missing_values)) * 100
pearson_corr_psmf, _ = pearsonr(original_missing_values, psmf_imputed_values)
spearman_corr_psmf, _ = spearmanr(original_missing_values, psmf_imputed_values)

# Calculate metrics for Mean Imputation
rmse_mean = np.sqrt(mean_squared_error(original_missing_values, mean_imputed_values))
mae_mean = mean_absolute_error(original_missing_values, mean_imputed_values)
mape_mean = np.mean(np.abs((original_missing_values - mean_imputed_values) / original_missing_values)) * 100
pearson_corr_mean, _ = pearsonr(original_missing_values, mean_imputed_values)
spearman_corr_mean, _ = spearmanr(original_missing_values, mean_imputed_values)

# Print results
print("Metrics for PSMF Imputation:")
print(f"RMSE: {rmse_psmf}")
print(f"MAE: {mae_psmf}")
print(f"MAPE: {mape_psmf}%")
print(f"Pearson Correlation Coefficient: {pearson_corr_psmf}")
print(f"Spearman Correlation Coefficient: {spearman_corr_psmf}")
print("\nMetrics for Mean Imputation:")
print(f"RMSE: {rmse_mean}")
print(f"MAE: {mae_mean}")
print(f"MAPE: {mape_mean}%")
print(f"Pearson Correlation Coefficient: {pearson_corr_mean}")
print(f"Spearman Correlation Coefficient: {spearman_corr_mean}")
# Out:
# Metrics for PSMF Imputation:
# RMSE: 10.204271559122764
# MAE: 4.060511238907783
# MAPE: 5.076612599382808%
# Pearson Correlation Coefficient: 0.995066196064281
# Spearman Correlation Coefficient: 0.9938551697528454
#
# Metrics for Mean Imputation:
# RMSE: 32.582225845093646
# MAE: 15.63017312831459
# MAPE: 20.188872270930148%
# Pearson Correlation Coefficient: 0.9460345200036698
# Spearman Correlation Coefficient: 0.9237285820830474

# %%
RMSE, MAE, MAPE, Correlation Coefficient (Pearson and Spearman), Normalized Mutual information
