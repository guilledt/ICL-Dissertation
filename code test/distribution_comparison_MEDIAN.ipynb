# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ks_2samp, wasserstein_distance
import numpy as np

def hellinger(p, q):
    """Calculate the Hellinger distance between two probability distributions."""
    return np.sqrt(np.sum((np.sqrt(p) - np.sqrt(q))**2)) / np.sqrt(2)

# Load the original dataset
original_path = '/Users/guillermodominguez/Documents/Imperial College London/Dissertation/rPSMF/ExperimentImpute/data/sp500_closing_prices.csv'
df_original = pd.read_csv(original_path, header=None)

# Impute missing values with the mean of each row
df_mean_imputed = df_original.copy()

# Apply row-wise mean imputation
for index, row in df_mean_imputed.iterrows():
    # Calculate the mean of the current row excluding NaNs
    row_mean = row.mean()
    # Fill NaNs in this row with the calculated mean
    df_mean_imputed.iloc[index] = row.fillna(row_mean)

# Median Imputation
df_median_imputed = df_original.copy()

for index, row in df_median_imputed.iterrows():
    row_median = row.median()  # Calculate the median of the current row excluding NaNs
    df_median_imputed.iloc[index] = row.fillna(row_median)

# Find rows that contain at least one NaN
mask = df_original.isna()
rows_with_nan = mask.any(axis=1)

# Get indices of these rows
rows_with_nan_indices = rows_with_nan[rows_with_nan].index.tolist()

# Initialize lists to store results for plotting
ks_stats_mean = []
ks_pvalues_mean = []
ks_stats_median = []
ks_pvalues_median = []
wasserstein_mean_list = []
wasserstein_median_list = []
hellinger_mean_list = []
hellinger_median_list = []

for idx, stock_row in enumerate(rows_with_nan_indices, start=1):
    
    # Drop NA values for the original for a fair comparison
    original_clean = df_original.iloc[stock_row].dropna()

    # Normalize the data for Hellinger distance calculation
    original_hist, _ = np.histogram(original_clean, bins=50, density=True)
    mean_hist, _ = np.histogram(df_mean_imputed.iloc[stock_row].dropna(), bins=50, density=True)
    median_hist, _ = np.histogram(df_median_imputed.iloc[stock_row].dropna(), bins=50, density=True)
    
    # Calculate the Hellinger distance
    hellinger_mean = hellinger(original_hist, mean_hist)
    hellinger_median = hellinger(original_hist, median_hist)
    
    # Append Hellinger distances to lists
    hellinger_mean_list.append(hellinger_mean)
    hellinger_median_list.append(hellinger_median)

    # KS Test between original and Mean imputed
    ks_stat_mean, ks_pvalue_mean = ks_2samp(original_clean, df_mean_imputed.iloc[stock_row].dropna())
    ks_stats_mean.append(ks_stat_mean)
    ks_pvalues_mean.append(ks_pvalue_mean)

    # KS Test between original and Median imputed
    ks_stat_median, ks_pvalue_median = ks_2samp(original_clean, df_median_imputed.iloc[stock_row].dropna())
    ks_stats_median.append(ks_stat_median)
    ks_pvalues_median.append(ks_pvalue_median)

    # Wasserstein Distance between original and Mean imputed
    wasserstein_mean = wasserstein_distance(original_clean, df_mean_imputed.iloc[stock_row].dropna())
    wasserstein_mean_list.append(wasserstein_mean)

    # Wasserstein Distance between original and Median imputed
    wasserstein_median = wasserstein_distance(original_clean, df_median_imputed.iloc[stock_row].dropna())
    wasserstein_median_list.append(wasserstein_median)

    # Plotting individual distributions
    plt.figure(figsize=(18, 6))

    # Original data distribution
    plt.subplot(1, 3, 1)
    df_original.iloc[stock_row].dropna().hist(bins=50, alpha=0.7, label='Original')
    plt.title(f'Original Data Distribution for Stock {idx}')
    plt.legend()

    # Distribution after mean imputation
    plt.subplot(1, 3, 2)
    df_mean_imputed.iloc[stock_row].hist(bins=50, alpha=0.7, color='green', label='Mean Imputed')
    plt.title(f'Mean Imputed Data Distribution for Stock {idx}')
    plt.legend()

    # Distribution after median imputation
    plt.subplot(1, 3, 3)
    df_median_imputed.iloc[stock_row].hist(bins=50, alpha=0.7, color='blue', label='Median Imputed')
    plt.title(f'Median Imputed Data Distribution for Stock {idx}')
    plt.legend()

    plt.show()

    # Print KS, Wasserstein, and Hellinger results for this stock
    print(f"Stock {idx} - KS Statistic Mean: {ks_stat_mean}, P-value Mean: {ks_pvalue_mean}")
    print(f"Stock {idx} - KS Statistic Median: {ks_stat_median}, P-value Median: {ks_pvalue_median}")
    print(f"Stock {idx} - Wasserstein Distance Mean: {wasserstein_mean}")
    print(f"Stock {idx} - Wasserstein Distance Median: {wasserstein_median}")
    print(f"Stock {idx} - Hellinger Distance Mean: {hellinger_mean}")
    print(f"Stock {idx} - Hellinger Distance Median: {hellinger_median}")
    print("\n" + "="*80 + "\n")

# Calculate means for the Wasserstein distances, KS statistics, and Hellinger distances
mean_wasserstein_mean = sum(wasserstein_mean_list) / len(wasserstein_mean_list)
mean_wasserstein_median = sum(wasserstein_median_list) / len(wasserstein_median_list)

mean_ks_stat_mean = sum(ks_stats_mean) / len(ks_stats_mean)
mean_ks_stat_median = sum(ks_stats_median) / len(ks_stats_median)

mean_hellinger_mean = sum(hellinger_mean_list) / len(hellinger_mean_list)
mean_hellinger_median = sum(hellinger_median_list) / len(hellinger_median_list)

# Plot Wasserstein distances with ordinal stock number and mean lines
plt.figure(figsize=(12, 6))
plt.plot(range(1, len(wasserstein_mean_list) + 1), wasserstein_mean_list, label='Mean Imputed', alpha=0.7, color='green')
plt.plot(range(1, len(wasserstein_median_list) + 1), wasserstein_median_list, label='Median Imputed', alpha=0.7, color='blue')
plt.axhline(mean_wasserstein_mean, color='green', linestyle='--', label='Mean Imputed')
plt.axhline(mean_wasserstein_median, color='blue', linestyle='--', label='Median Imputed')
plt.xlabel('Stock Number (Ordinal)')
plt.ylabel('Wasserstein Distance')
plt.title('Wasserstein Distance Comparison for Mean and Median Imputed Data')
plt.legend()
plt.show()

# Plot KS statistics with ordinal stock number and mean lines
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(range(1, len(ks_stats_mean) + 1), ks_stats_mean, label='KS Statistic Mean', alpha=0.7, color='green')
plt.plot(range(1, len(ks_stats_median) + 1), ks_stats_median, label='KS Statistic Median', alpha=0.7, color='blue')
plt.axhline(mean_ks_stat_mean, color='green', linestyle='--', label='Mean KS Statistic Mean')
plt.axhline(mean_ks_stat_median, color='blue', linestyle='--', label='Mean KS Statistic Median')
plt.xlabel('Stock Number (Ordinal)')
plt.ylabel('KS Statistic')
plt.title('KS Statistic Comparison for Mean and Median Imputed Data')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(range(1, len(ks_pvalues_mean) + 1), ks_pvalues_mean, label='P-value Mean', alpha=0.7, color='green')
plt.plot(range(1, len(ks_pvalues_median) + 1), ks_pvalues_median, label='P-value Median', alpha=0.7, color='blue')
plt.xlabel('Stock Number (Ordinal)')
plt.ylabel('P-value')
plt.title('P-value Comparison for Mean and Median Imputed Data')
plt.legend()
plt.tight_layout()
plt.show()

# Plot Hellinger distances with ordinal stock number and mean lines
plt.figure(figsize=(12, 6))
plt.plot(range(1, len(hellinger_mean_list) + 1), hellinger_mean_list, label='Mean Imputed', alpha=0.7, color='green')
plt.plot(range(1, len(hellinger_median_list) + 1), hellinger_median_list, label='Median Imputed', alpha=0.7, color='blue')
plt.axhline(mean_hellinger_mean, color='green', linestyle='--', label='Mean Imputed')
plt.axhline(mean_hellinger_median, color='blue', linestyle='--', label='Median Imputed')
plt.xlabel('Stock Number (Ordinal)')
plt.ylabel('Hellinger Distance')
plt.title('Hellinger Distance Comparison for Mean and Median Imputed Data')
plt.legend()
plt.show()
# Out:
# Stock 1 - KS Statistic Mean: 0.08186700161471461, P-value Mean: 0.0008168855377024989
# Stock 1 - KS Statistic Median: 0.07776632890413855, P-value Median: 0.0017457533161395623
# Stock 1 - Wasserstein Distance Mean: 1.413084662895336
# Stock 1 - Wasserstein Distance Median: 1.4103524202412432
# Stock 1 - Hellinger Distance Mean: 0.1761931487459466
# Stock 1 - Hellinger Distance Median: 0.17716025963007528
#
# ================================================================================
# Stock 2 - KS Statistic Mean: 0.5044588056899415, P-value Mean: 1.5901663749380204e-10
# Stock 2 - KS Statistic Median: 0.48252581413820494, P-value Median: 1.2815435197442486e-09
# Stock 2 - Wasserstein Distance Mean: 3.7290970713343246
# Stock 2 - Wasserstein Distance Median: 3.686716549931402
# Stock 2 - Hellinger Distance Mean: 1.7704147547506732
# Stock 2 - Hellinger Distance Median: 1.7704147547506732
#
# ================================================================================
# Stock 3 - KS Statistic Mean: 0.5020967912151391, P-value Mean: 2.652383191858639e-30
# Stock 3 - KS Statistic Median: 0.4401095330404306, P-value Median: 4.486143897585788e-23
# Stock 3 - Wasserstein Distance Mean: 2.742096181860985
# Stock 3 - Wasserstein Distance Median: 2.694592311580397
# Stock 3 - Hellinger Distance Mean: 1.2303294751681841
# Stock 3 - Hellinger Distance Median: 1.2106394685582964
#
# ================================================================================
# Stock 4 - KS Statistic Mean: 0.44541929685213827, P-value Mean: 6.204006559200715e-25
# Stock 4 - KS Statistic Median: 0.4396346306592534, P-value Median: 2.831853594094944e-24
# Stock 4 - Wasserstein Distance Mean: 1.9581155954138505
# Stock 4 - Wasserstein Distance Median: 1.9574153463483956
# Stock 4 - Hellinger Distance Mean: 0.8478611620977592
# Stock 4 - Hellinger Distance Median: 0.8478611620977592
#
# ================================================================================
# Stock 5 - KS Statistic Mean: 0.0008050232439403677, P-value Mean: 1.0
# Stock 5 - KS Statistic Median: 0.0007936492891594205, P-value Median: 1.0
# Stock 5 - Wasserstein Distance Mean: 0.011288686716214281
# Stock 5 - Wasserstein Distance Median: 0.011286703910049701
# Stock 5 - Hellinger Distance Mean: 0.0034855036950297686
# Stock 5 - Hellinger Distance Median: 0.0034855036950297686
#
# ================================================================================
# Stock 6 - KS Statistic Mean: 0.20561790403214503, P-value Mean: 2.9117113464442813e-19
# Stock 6 - KS Statistic Median: 0.16204831098444145, P-value Median: 4.173065685822782e-12
# Stock 6 - Wasserstein Distance Mean: 1.9411798917029222
# Stock 6 - Wasserstein Distance Median: 1.7702726954165304
# Stock 6 - Hellinger Distance Mean: 0.49763417883970973
# Stock 6 - Hellinger Distance Median: 0.3673110208888954
#
# ================================================================================
# Stock 7 - KS Statistic Mean: 0.04216123027585866, P-value Mean: 0.22197851624607715
# Stock 7 - KS Statistic Median: 0.03412497367631654, P-value Median: 0.46531139270156013
# Stock 7 - Wasserstein Distance Mean: 0.28984841791440524
# Stock 7 - Wasserstein Distance Median: 0.27251353765251657
# Stock 7 - Hellinger Distance Mean: 0.2158341288121306
# Stock 7 - Hellinger Distance Median: 0.1438893639250496
#
# ================================================================================
# Stock 8 - KS Statistic Mean: 0.2944985055904086, P-value Mean: 3.29225602557043e-30
# Stock 8 - KS Statistic Median: 0.2767100052527329, P-value Median: 1.1223361729499244e-26
# Stock 8 - Wasserstein Distance Mean: 1.4145332145478908
# Stock 8 - Wasserstein Distance Median: 1.4102673655208346
# Stock 8 - Hellinger Distance Mean: 0.9858900230373847
# Stock 8 - Hellinger Distance Median: 0.9513632774165969
#
# ================================================================================
# Stock 9 - KS Statistic Mean: 0.006625186828607158, P-value Mean: 0.9999999999999963
# Stock 9 - KS Statistic Median: 0.006349137377415193, P-value Median: 0.9999999999999977
# Stock 9 - Wasserstein Distance Mean: 0.09713761322028464
# Stock 9 - Wasserstein Distance Median: 0.09685481268575025
# Stock 9 - Hellinger Distance Mean: 0.02074738650252727
# Stock 9 - Hellinger Distance Median: 0.02686416771347202
#
# ================================================================================
# Stock 10 - KS Statistic Mean: 0.5447019988195088, P-value Mean: 2.9134626461168744e-28
# Stock 10 - KS Statistic Median: 0.4525216605577457, P-value Median: 3.26597761096501e-19
# Stock 10 - Wasserstein Distance Mean: 1.58191608751306
# Stock 10 - Wasserstein Distance Median: 1.556925913241178
# Stock 10 - Hellinger Distance Mean: 1.3205672626385536
# Stock 10 - Hellinger Distance Median: 1.3568300907647612
#
# ================================================================================
# Stock 11 - KS Statistic Mean: 0.5013946099709995, P-value Mean: 7.020393840670315e-43
# Stock 11 - KS Statistic Median: 0.41268633282228423, P-value Median: 1.1246934142035484e-28
# Stock 11 - Wasserstein Distance Mean: 6.404231730781209
# Stock 11 - Wasserstein Distance Median: 6.289725400373127
# Stock 11 - Hellinger Distance Mean: 0.9214882746455358
# Stock 11 - Hellinger Distance Median: 0.7289721721984374
#
# ================================================================================
# Stock 12 - KS Statistic Mean: 0.0041399283048360845, P-value Mean: 0.9999999999999997
# Stock 12 - KS Statistic Median: 0.003968226209243805, P-value Median: 1.0
# Stock 12 - Wasserstein Distance Mean: 0.04786906739824247
# Stock 12 - Wasserstein Distance Median: 0.047809590007192405
# Stock 12 - Hellinger Distance Mean: 0.023046755818585517
# Stock 12 - Hellinger Distance Median: 0.019550664454022308
#
# ================================================================================
# Stock 13 - KS Statistic Mean: 0.44765366131529755, P-value Mean: 4.161193016784169e-44
# Stock 13 - KS Statistic Median: 0.3807628843371496, P-value Median: 1.1318978455376221e-31
# Stock 13 - Wasserstein Distance Mean: 8.66586283672026
# Stock 13 - Wasserstein Distance Median: 8.356780540378633
# Stock 13 - Hellinger Distance Mean: 0.6836369531513677
# Stock 13 - Hellinger Distance Median: 0.5697964496815261
#
# ================================================================================
# Stock 14 - KS Statistic Mean: 0.0358955299431773, P-value Mean: 0.40268952829441107
# Stock 14 - KS Statistic Median: 0.03571207749031609, P-value Median: 0.40905386686545875
# Stock 14 - Wasserstein Distance Mean: 0.2159115721722987
# Stock 14 - Wasserstein Distance Median: 0.21590323494619745
# Stock 14 - Hellinger Distance Mean: 0.20574908352585386
# Stock 14 - Hellinger Distance Median: 0.20574908352585386
#
# ================================================================================
# Stock 15 - KS Statistic Mean: 0.03620128403127932, P-value Mean: 0.39221480249103186
# Stock 15 - KS Statistic Median: 0.03571207749031609, P-value Median: 0.40905386686545875
# Stock 15 - Wasserstein Distance Mean: 0.1929197750520123
# Stock 15 - Wasserstein Distance Median: 0.19289297723626836
# Stock 15 - Hellinger Distance Mean: 0.21242196348987402
# Stock 15 - Hellinger Distance Median: 0.21242196348987402
#
# ================================================================================
# Stock 16 - KS Statistic Mean: 0.34123616889091607, P-value Mean: 3.8157076734928466e-32
# Stock 16 - KS Statistic Median: 0.33955520254169974, P-value Median: 7.939714697092302e-32
# Stock 16 - Wasserstein Distance Mean: 4.944857600708678
# Stock 16 - Wasserstein Distance Median: 4.944528896892867
# Stock 16 - Hellinger Distance Mean: 0.7834106577707995
# Stock 16 - Hellinger Distance Median: 0.7834106577707995
#
# ================================================================================
# Stock 17 - KS Statistic Mean: 0.11544856520233804, P-value Mean: 7.674264943471248e-07
# Stock 17 - KS Statistic Median: 0.1126722470010794, P-value Median: 1.547189479219639e-06
# Stock 17 - Wasserstein Distance Mean: 30.978738789314797
# Stock 17 - Wasserstein Distance Median: 30.967587912588343
# Stock 17 - Hellinger Distance Mean: 0.06345002092046904
# Stock 17 - Hellinger Distance Median: 0.06378762364177192
#
# ================================================================================
# Stock 18 - KS Statistic Mean: 0.4695986002233196, P-value Mean: 6.371324219506661e-46
# Stock 18 - KS Statistic Median: 0.3903891977760127, P-value Median: 1.995193762136903e-31
# Stock 18 - Wasserstein Distance Mean: 5.472071691675429
# Stock 18 - Wasserstein Distance Median: 5.279250094968402
# Stock 18 - Hellinger Distance Mean: 0.7894108662698024
# Stock 18 - Hellinger Distance Median: 0.7813960866505906
#
# ================================================================================
# Stock 19 - KS Statistic Mean: 0.307727221150573, P-value Mean: 9.081156005410254e-34
# Stock 19 - KS Statistic Median: 0.2678709846762518, P-value Median: 1.348047619711121e-25
# Stock 19 - Wasserstein Distance Mean: 1.617072119832363
# Stock 19 - Wasserstein Distance Median: 1.5947036346908114
# Stock 19 - Hellinger Distance Mean: 0.9218231659349501
# Stock 19 - Hellinger Distance Median: 0.8846762749580956
#
# ================================================================================
# Stock 20 - KS Statistic Mean: 0.3040196642692408, P-value Mean: 5.876373230659287e-33
# Stock 20 - KS Statistic Median: 0.2687978738965849, P-value Median: 8.979349506272961e-26
# Stock 20 - Wasserstein Distance Mean: 1.667914083455546
# Stock 20 - Wasserstein Distance Median: 1.6414281202878005
# Stock 20 - Hellinger Distance Mean: 0.8633334216481499
# Stock 20 - Hellinger Distance Median: 0.7967049635498313
#
# ================================================================================
# Stock 21 - KS Statistic Mean: 0.0023087359528143774, P-value Mean: 1.0
# Stock 21 - KS Statistic Median: 0.0019857029388403494, P-value Median: 1.0
# Stock 21 - Wasserstein Distance Mean: 0.03471678408563647
# Stock 21 - Wasserstein Distance Median: 0.03393804480151194
# Stock 21 - Hellinger Distance Mean: 0.010200487019972396
# Stock 21 - Hellinger Distance Median: 0.005605174404516143
#
# ================================================================================
# Stock 22 - KS Statistic Mean: 0.14011743581437208, P-value Mean: 1.496816474723797e-09
# Stock 22 - KS Statistic Median: 0.13567396533400086, P-value Median: 5.558203204766455e-09
# Stock 22 - Wasserstein Distance Mean: 1.836315191124871
# Stock 22 - Wasserstein Distance Median: 1.832408724793266
# Stock 22 - Hellinger Distance Mean: 0.4252455052341753
# Stock 22 - Hellinger Distance Median: 0.4437839877361089
#
# ================================================================================
# Stock 23 - KS Statistic Mean: 0.02563066389829485, P-value Mean: 0.8012226121687381
# Stock 23 - KS Statistic Median: 0.02460214608536167, P-value Median: 0.8388425366583524
# Stock 23 - Wasserstein Distance Mean: 0.6663369553264291
# Stock 23 - Wasserstein Distance Median: 0.665814297459296
# Stock 23 - Hellinger Distance Mean: 0.060125671838897034
# Stock 23 - Hellinger Distance Median: 0.060125671838897034
#
# ================================================================================
# Stock 24 - KS Statistic Mean: 0.2446337514930667, P-value Mean: 3.8857656018633437e-23
# Stock 24 - KS Statistic Median: 0.23950669682105633, P-value Median: 3.4608741333656e-22
# Stock 24 - Wasserstein Distance Mean: 2.7625904277940743
# Stock 24 - Wasserstein Distance Median: 2.760955562696675
# Stock 24 - Hellinger Distance Mean: 0.6249295137267696
# Stock 24 - Hellinger Distance Median: 0.6087364638671959
#
# ================================================================================
# Stock 25 - KS Statistic Mean: 0.13012476833465714, P-value Mean: 1.667229348696696e-08
# Stock 25 - KS Statistic Median: 0.1187450357426529, P-value Median: 3.7356071160764254e-07
# Stock 25 - Wasserstein Distance Mean: 0.6042974100159407
# Stock 25 - Wasserstein Distance Median: 0.595850714853058
# Stock 25 - Hellinger Distance Mean: 0.50182684474139
# Stock 25 - Hellinger Distance Median: 0.46634560434942735
#
# ================================================================================
# Stock 26 - KS Statistic Mean: 0.03607898239603852, P-value Mean: 0.39638468892932344
# Stock 26 - KS Statistic Median: 0.03571207749031609, P-value Median: 0.40905386686545875
# Stock 26 - Wasserstein Distance Mean: 0.1265744280466411
# Stock 26 - Wasserstein Distance Median: 0.12656222673228376
# Stock 26 - Hellinger Distance Mean: 0.285835761876356
# Stock 26 - Hellinger Distance Median: 0.285835761876356
#
# ================================================================================
# Stock 27 - KS Statistic Mean: 0.038341562647993474, P-value Mean: 0.3236933264422643
# Stock 27 - KS Statistic Median: 0.03571207749031609, P-value Median: 0.40905386686545875
# Stock 27 - Wasserstein Distance Mean: 0.11061799577170547
# Stock 27 - Wasserstein Distance Median: 0.10997240739218261
# Stock 27 - Hellinger Distance Mean: 0.3004638821795484
# Stock 27 - Hellinger Distance Median: 0.2946157869757356
#
# ================================================================================
# Stock 28 - KS Statistic Mean: 0.0008505190630641561, P-value Mean: 1.0
# Stock 28 - KS Statistic Median: 0.0007911217436525434, P-value Median: 1.0
# Stock 28 - Wasserstein Distance Mean: 0.006030787680938724
# Stock 28 - Wasserstein Distance Median: 0.00601486449512582
# Stock 28 - Hellinger Distance Mean: 0.003279845041119812
# Stock 28 - Hellinger Distance Median: 0.003279845041119812
#
# ================================================================================
# Stock 29 - KS Statistic Mean: 0.0067683235810770655, P-value Mean: 0.999999999999996
# Stock 29 - KS Statistic Median: 0.006349137377415193, P-value Median: 0.9999999999999977
# Stock 29 - Wasserstein Distance Mean: 0.08930589706604566
# Stock 29 - Wasserstein Distance Median: 0.08880782088991432
# Stock 29 - Hellinger Distance Mean: 0.03341414673664183
# Stock 29 - Hellinger Distance Median: 0.03094624743710461
#
# ================================================================================
# Stock 30 - KS Statistic Mean: 0.33472342644410624, P-value Mean: 2.6505326317688298e-43
# Stock 30 - KS Statistic Median: 0.23950669682105633, P-value Median: 3.4608741333656e-22
# Stock 30 - Wasserstein Distance Mean: 5.331193380191033
# Stock 30 - Wasserstein Distance Median: 4.474684573361871
# Stock 30 - Hellinger Distance Mean: 0.504190331732699
# Stock 30 - Hellinger Distance Median: 0.3218074982275865
#
# ================================================================================
# Stock 31 - KS Statistic Mean: 0.19979883634248266, P-value Mean: 2.55607630960101e-17
# Stock 31 - KS Statistic Median: 0.1895901366753485, P-value Median: 1.2491032193445025e-15
# Stock 31 - Wasserstein Distance Mean: 3.843182270540848
# Stock 31 - Wasserstein Distance Median: 3.8135521250835214
# Stock 31 - Hellinger Distance Mean: 0.4145873091101527
# Stock 31 - Hellinger Distance Median: 0.3634896718166741
#
# ================================================================================
# Stock 32 - KS Statistic Mean: 0.15497159192552362, P-value Mean: 2.1957898615748985e-11
# Stock 32 - KS Statistic Median: 0.14733915806195394, P-value Median: 2.4867183305721996e-10
# Stock 32 - Wasserstein Distance Mean: 0.8467325676462962
# Stock 32 - Wasserstein Distance Median: 0.8450846472962239
# Stock 32 - Hellinger Distance Mean: 0.4756788090553693
# Stock 32 - Hellinger Distance Median: 0.4756788090553693
#
# ================================================================================
# Stock 33 - KS Statistic Mean: 0.3511099394702966, P-value Mean: 1.1220744004294266e-37
# Stock 33 - KS Statistic Median: 0.31572676727561555, P-value Median: 2.0297714585646755e-30
# Stock 33 - Wasserstein Distance Mean: 5.181416825757046
# Stock 33 - Wasserstein Distance Median: 4.920234227356139
# Stock 33 - Hellinger Distance Mean: 0.6881679097307202
# Stock 33 - Hellinger Distance Median: 0.5854527567208437
#
# ================================================================================
# Stock 34 - KS Statistic Mean: 0.36728584494668687, P-value Mean: 3.1880707747918e-45
# Stock 34 - KS Statistic Median: 0.2903097696584591, P-value Median: 3.621088642221162e-28
# Stock 34 - Wasserstein Distance Mean: 7.716849464958814
# Stock 34 - Wasserstein Distance Median: 7.06577690627482
# Stock 34 - Hellinger Distance Mean: 0.5201985618795134
# Stock 34 - Hellinger Distance Median: 0.4233048416550966
#
# ================================================================================
# Stock 35 - KS Statistic Mean: 0.27290757302707513, P-value Mean: 5.971870916896547e-29
# Stock 35 - KS Statistic Median: 0.23709293089753772, P-value Median: 6.775518074355466e-22
# Stock 35 - Wasserstein Distance Mean: 3.3921807780214683
# Stock 35 - Wasserstein Distance Median: 3.34843982540212
# Stock 35 - Hellinger Distance Mean: 0.43363435435130865
# Stock 35 - Hellinger Distance Median: 0.4297254664311763
#
# ================================================================================

# %%
import pandas as pd
from scipy.stats import ks_2samp, wasserstein_distance
import numpy as np

def hellinger(p, q):
    """Calculate the Hellinger distance between two probability distributions."""
    return np.sqrt(np.sum((np.sqrt(p) - np.sqrt(q))**2)) / np.sqrt(2)

# Load the original dataset
original_path = '/Users/guillermodominguez/Documents/Imperial College London/Dissertation/rPSMF/ExperimentImpute/data/sp500_closing_prices_masked_10percent.csv'
df_original = pd.read_csv(original_path, header=None)

# Impute missing values with the mean of each row
df_mean_imputed = df_original.copy()

# Apply row-wise mean imputation
for index, row in df_mean_imputed.iterrows():
    row_mean = row.mean()
    df_mean_imputed.iloc[index] = row.fillna(row_mean)

# Median Imputation
df_median_imputed = df_original.copy()

for index, row in df_median_imputed.iterrows():
    row_median = row.median()
    df_median_imputed.iloc[index] = row.fillna(row_median)

# Find rows that contain at least one NaN
mask = df_original.isna()
rows_with_nan = mask.any(axis=1)
rows_with_nan_indices = rows_with_nan[rows_with_nan].index.tolist()

# Initialize lists to store results
ks_stats_mean = []
ks_pvalues_mean = []
ks_stats_median = []
ks_pvalues_median = []
wasserstein_mean_list = []
wasserstein_median_list = []
hellinger_mean_list = []
hellinger_median_list = []

for idx, stock_row in enumerate(rows_with_nan_indices, start=1):
    
    # Drop NA values for the original for a fair comparison
    original_clean = df_original.iloc[stock_row].dropna()

    # Normalize the data for Hellinger distance calculation
    original_hist, _ = np.histogram(original_clean, bins=50, density=True)
    mean_hist, _ = np.histogram(df_mean_imputed.iloc[stock_row].dropna(), bins=50, density=True)
    median_hist, _ = np.histogram(df_median_imputed.iloc[stock_row].dropna(), bins=50, density=True)
    
    # Calculate the Hellinger distance
    hellinger_mean = hellinger(original_hist, mean_hist)
    hellinger_median = hellinger(original_hist, median_hist)
    
    # Append Hellinger distances to lists
    hellinger_mean_list.append(hellinger_mean)
    hellinger_median_list.append(hellinger_median)

    # KS Test between original and Mean imputed
    ks_stat_mean, ks_pvalue_mean = ks_2samp(original_clean, df_mean_imputed.iloc[stock_row].dropna())
    ks_stats_mean.append(ks_stat_mean)
    ks_pvalues_mean.append(ks_pvalue_mean)

    # KS Test between original and Median imputed
    ks_stat_median, ks_pvalue_median = ks_2samp(original_clean, df_median_imputed.iloc[stock_row].dropna())
    ks_stats_median.append(ks_stat_median)
    ks_pvalues_median.append(ks_pvalue_median)

    # Wasserstein Distance between original and Mean imputed
    wasserstein_mean = wasserstein_distance(original_clean, df_mean_imputed.iloc[stock_row].dropna())
    wasserstein_mean_list.append(wasserstein_mean)

    # Wasserstein Distance between original and Median imputed
    wasserstein_median = wasserstein_distance(original_clean, df_median_imputed.iloc[stock_row].dropna())
    wasserstein_median_list.append(wasserstein_median)

# Calculate means for the Wasserstein distances, KS statistics, and Hellinger distances
mean_wasserstein_mean = np.mean(wasserstein_mean_list)
mean_wasserstein_median = np.mean(wasserstein_median_list)

mean_ks_stat_mean = np.mean(ks_stats_mean)
mean_ks_stat_median = np.mean(ks_stats_median)

mean_hellinger_mean = np.mean(hellinger_mean_list)
mean_hellinger_median = np.mean(hellinger_median_list)

# %%
# Calculate overall means for the Wasserstein distances, KS statistics, and Hellinger distances
mean_wasserstein_mean = np.mean(wasserstein_mean_list)
mean_wasserstein_median = np.mean(wasserstein_median_list)

mean_ks_stat_mean = np.mean(ks_stats_mean)
mean_ks_stat_median = np.mean(ks_stats_median)

mean_hellinger_mean = np.mean(hellinger_mean_list)
mean_hellinger_median = np.mean(hellinger_median_list)

# Print the overall means
print(f"Overall Mean Wasserstein Distance for Mean Imputation: {mean_wasserstein_mean}")
print(f"Overall Mean Wasserstein Distance for Median Imputation: {mean_wasserstein_median}")

print(f"Overall Mean KS Statistic for Mean Imputation: {mean_ks_stat_mean}")
print(f"Overall Mean KS Statistic for Median Imputation: {mean_ks_stat_median}")

print(f"Overall Mean Hellinger Distance for Mean Imputation: {mean_hellinger_mean}")
print(f"Overall Mean Hellinger Distance for Median Imputation: {mean_hellinger_median}")
# Out:
# Overall Mean Wasserstein Distance for Mean Imputation: 1.3751773595216852
# Overall Mean Wasserstein Distance for Median Imputation: 1.343007701550465
# Overall Mean KS Statistic for Mean Imputation: 0.05700940147215666
# Overall Mean KS Statistic for Median Imputation: 0.05068445454496621
# Overall Mean Hellinger Distance for Mean Imputation: 0.14802475426292838
# Overall Mean Hellinger Distance for Median Imputation: 0.13579836270271398

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr, spearmanr

# Paths to the CSV files
original_path = '/Users/guillermodominguez/Documents/Imperial College London/Dissertation/rPSMF/ExperimentImpute/data/cleaned_sp500_stocks_matrix.csv'
masked_path = '/Users/guillermodominguez/Documents/Imperial College London/Dissertation/rPSMF/ExperimentImpute/data/cleaned_sp500_stocks_matrix_masked_20percent.csv'

# Load the datasets
df_original = pd.read_csv(original_path, header=None)
df_masked = pd.read_csv(masked_path, header=None)

# Convert all data to numeric, setting errors='coerce' to handle non-numeric values
df_original = df_original.apply(pd.to_numeric, errors='coerce')
df_masked = df_masked.apply(pd.to_numeric, errors='coerce')

# Create a mask of the missing values
mask = df_masked.isna()

# Impute missing values using mean imputation
df_mean_imputed = df_masked.copy()
for index, row in df_mean_imputed.iterrows():
    row_mean = row.mean()
    df_mean_imputed.iloc[index] = row.fillna(row_mean)

# Impute missing values using median imputation
df_median_imputed = df_masked.copy()
for index, row in df_median_imputed.iterrows():
    row_median = row.median()
    df_median_imputed.iloc[index] = row.fillna(row_median)

# Extract only the values that were originally missing
original_missing_values = df_original[mask].values
mean_imputed_values = df_mean_imputed[mask].values
median_imputed_values = df_median_imputed[mask].values

# Ensure no NaN values are present in the extracted values
original_missing_values = original_missing_values[~np.isnan(original_missing_values)]
mean_imputed_values = mean_imputed_values[~np.isnan(mean_imputed_values)]
median_imputed_values = median_imputed_values[~np.isnan(median_imputed_values)]

# Calculate metrics for Median Imputation
rmse_median = np.sqrt(mean_squared_error(original_missing_values, median_imputed_values))
mae_median = mean_absolute_error(original_missing_values, median_imputed_values)
mape_median = np.mean(np.abs((original_missing_values - median_imputed_values) / original_missing_values)) * 100
pearson_corr_median, _ = pearsonr(original_missing_values, median_imputed_values)
spearman_corr_median, _ = spearmanr(original_missing_values, median_imputed_values)

# Calculate metrics for Mean Imputation
rmse_mean = np.sqrt(mean_squared_error(original_missing_values, mean_imputed_values))
mae_mean = mean_absolute_error(original_missing_values, mean_imputed_values)
mape_mean = np.mean(np.abs((original_missing_values - mean_imputed_values) / original_missing_values)) * 100
pearson_corr_mean, _ = pearsonr(original_missing_values, mean_imputed_values)
spearman_corr_mean, _ = spearmanr(original_missing_values, mean_imputed_values)

# Print results
print("Metrics for Median Imputation:")
print(f"RMSE: {rmse_median}")
print(f"MAE: {mae_median}")
print(f"MAPE: {mape_median}%")
print(f"Pearson Correlation Coefficient: {pearson_corr_median}")
print(f"Spearman Correlation Coefficient: {spearman_corr_median}")
print("\nMetrics for Mean Imputation:")
print(f"RMSE: {rmse_mean}")
print(f"MAE: {mae_mean}")
print(f"MAPE: {mape_mean}%")
print(f"Pearson Correlation Coefficient: {pearson_corr_mean}")
print(f"Spearman Correlation Coefficient: {spearman_corr_mean}")
# Out:
# Metrics for Median Imputation:
# RMSE: 33.68919398673326
# MAE: 15.456725157482982
# MAPE: 19.0963965215898%
# Pearson Correlation Coefficient: 0.9437959923537576
# Spearman Correlation Coefficient: 0.9201231653297652
#
# Metrics for Mean Imputation:
# RMSE: 32.582225845093646
# MAE: 15.63017312831459
# MAPE: 20.188872270930148%
# Pearson Correlation Coefficient: 0.9460345200036698
# Spearman Correlation Coefficient: 0.9237285820830474
