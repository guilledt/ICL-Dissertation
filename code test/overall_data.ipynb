# %%
zero_percent_data = {
    "Evaluation Metric": ["Wasserstein Distance", "KS Statistic", "Hellinger Distance"],
    "Mean Imputation": [3.0838310815502257, 0.21420625522291223, 0.5091002034776553],
    "BPMF": [25.55787019367595, 0.38023374560308637, 0.9153463811622079],
    "KNN": [6.88119409794282, 0.2479789607731481, 0.3109463638639546],
    "LR": [18.44600717678526, 0.3382364113019974, 0.39372561618927787],
    "Median Imputation": [3.002454429365313, 0.18969584481526744, 0.47717195990841715],
    "MLESMF": [5.419443371492278, 0.22698638636523544, 0.6522071841587167],
    "NOCB & FOCB": [5.044235503157212, 0.31998286568463985, 0.4904172281920558],
    "PMF": [25.55787019367595, 0.38023374560308637, 0.9153463811622079],
    "PSMF": [15.088536305789454, 0.2941856826220132, 0.47220652988965356],
    "Range Imputation": [12.270603936937524, 0.3411930098171897, 0.6633786999668501],
    "rPSMF": [14.084549396666914, 0.2929120307899972, 0.44875716989332987],
    "TMF": [4.902895105155023, 0.22993227197794028, 0.37657358600304514]
}

# %% [markdown]
# 0% mask
# Overall Mean Wasserstein Distance BPMF: 25.55787019367595
# Overall Mean Wasserstein Distance Mean Imputation: 3.0838310815502257
# Overall Mean KS Statistic BPMF: 0.38023374560308637
# Overall Mean KS Statistic Mean Imputation: 0.21420625522291223
# Overall Mean Hellinger Distance BPMF: 0.9153463811622079
# Overall Mean Hellinger Distance Mean Imputation: 0.5091002034776553
#
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0838310815502257
# Overall Mean Wasserstein Distance for KNN Imputation: 6.88119409794282
# Overall Mean KS Statistic for Mean Imputation: 0.21420625522291223
# Overall Mean KS Statistic for KNN Imputation: 0.2479789607731481
# Overall Mean Hellinger Distance for Mean Imputation: 0.5091002034776553
# Overall Mean Hellinger Distance for KNN Imputation: 0.3109463638639546
#
# Overall Mean Wasserstein Distance LR Imputation: 18.44600717678526
# Overall Mean Wasserstein Distance Mean Imputation: 3.0838310815502257
# Overall Mean KS Statistic LR Imputation: 0.3382364113019974
# Overall Mean KS Statistic Mean Imputation: 0.21420625522291223
# Overall Mean Hellinger Distance LR Imputation: 0.39372561618927787
# Overall Mean Hellinger Distance Mean Imputation: 0.5091002034776553
#
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0838310815502257
# Overall Mean Wasserstein Distance for Median Imputation: 3.002454429365313
# Overall Mean KS Statistic for Mean Imputation: 0.21420625522291223
# Overall Mean KS Statistic for Median Imputation: 0.18969584481526744
# Overall Mean Hellinger Distance for Mean Imputation: 0.5091002034776553
# Overall Mean Hellinger Distance for Median Imputation: 0.47717195990841715
#
# Overall Mean Wasserstein Distance for MLESMF Imputation: 5.419443371492278
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0838310815502257
# Overall Mean KS Statistic for MLESMF Imputation: 0.22698638636523544
# Overall Mean KS Statistic for Mean Imputation: 0.21420625522291223
# Overall Mean Hellinger Distance for MLESMF Imputation: 0.6522071841587167
# Overall Mean Hellinger Distance for Mean Imputation: 0.5091002034776553
#
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0838310815502257
# Overall Mean Wasserstein Distance for NOCB & FOCB Imputation: 5.044235503157212
# Overall Mean KS Statistic for Mean Imputation: 0.21420625522291223
# Overall Mean KS Statistic for NOCB & FOCB Imputation: 0.31998286568463985
# Overall Mean Hellinger Distance for Mean Imputation: 0.5091002034776553
# Overall Mean Hellinger Distance for NOCB & FOCB Imputation: 0.4904172281920558
#
# Overall Mean Wasserstein Distance for PMF Imputation: 25.55787019367595
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0838310815502257
# Overall Mean KS Statistic for PMF Imputation: 0.38023374560308637
# Overall Mean KS Statistic for Mean Imputation: 0.21420625522291223
# Overall Mean Hellinger Distance for PMF Imputation: 0.9153463811622079
# Overall Mean Hellinger Distance for Mean Imputation: 0.5091002034776553
#
# Overall Mean Wasserstein Distance for PSMF Imputation: 15.088536305789454
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0838310815502257
# Overall Mean KS Statistic for PSMF Imputation: 0.2941856826220132
# Overall Mean KS Statistic for Mean Imputation: 0.21420625522291223
# Overall Mean Hellinger Distance for PSMF Imputation: 0.47220652988965356
# Overall Mean Hellinger Distance for Mean Imputation: 0.5091002034776553
#
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0838310815502257
# Overall Mean Wasserstein Distance for Range Imputation: 12.270603936937524
# Overall Mean KS Statistic for Mean Imputation: 0.21420625522291223
# Overall Mean KS Statistic for Range Imputation: 0.3411930098171897
# Overall Mean Hellinger Distance for Mean Imputation: 0.5091002034776553
# Overall Mean Hellinger Distance for Range Imputation: 0.6633786999668501
#
# Overall Mean Wasserstein Distance for rPSMF Imputation: 14.084549396666914
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0838310815502257
# Overall Mean KS Statistic for rPSMF Imputation: 0.2929120307899972
# Overall Mean KS Statistic for Mean Imputation: 0.21420625522291223
# Overall Mean Hellinger Distance for rPSMF Imputation: 0.44875716989332987
# Overall Mean Hellinger Distance for Mean Imputation: 0.5091002034776553
#
# Overall Mean Wasserstein Distance for TMF Imputation: 4.902895105155023
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0838310815502257
# Overall Mean KS Statistic for TMF Imputation: 0.22993227197794028
# Overall Mean KS Statistic for Mean Imputation: 0.21420625522291223
# Overall Mean Hellinger Distance for TMF Imputation: 0.37657358600304514
# Overall Mean Hellinger Distance for Mean Imputation: 0.5091002034776553

# %%
ten_percent_data = {
    "Evaluation Metric": ["Wasserstein Distance", "KS Statistic", "Hellinger Distance"],
    "Mean Imputation": [1.3751773595216852, 0.05700940147215666, 0.14802475426292838],
    "BPMF": [2.761758675328811, 0.0599967896983296, 0.2397145458289728],
    "KNN": [1.3094405985191355, 0.042316099797066825, 0.08484124337129127],
    "LR": [2.0681279596199347, 0.051837398305324085, 0.10613580015500974],
    "Median Imputation": [1.343007701550465, 0.05068445454496621, 0.13579836270271398],
    "MLESMF": [1.6641920977685893, 0.05872572547974246, 0.17470225798756067],
    "NOCB & FOCB": [5.044235503157212, 0.31998286568463985, 0.4904172281920558],
    "PMF": [3.0342668994775623, 0.06325745130110084, 0.33221724914707673],
    "PSMF": [1.5783120491982838, 0.04303515363518428, 0.084795783483168],
    "Range Imputation": [3.0772232971035525, 0.08637207159590451, 0.2710489511191072],
    "rPSMF": [1.4615806621863208, 0.0394832166221099, 0.0837293302582936],
    "TMF": [1.7775620885958028, 0.060914917766279685, 0.15934921648482062]
}

# %% [markdown]
# 10%
# Overall Mean Wasserstein Distance BPMF: 2.761758675328811
# Overall Mean Wasserstein Distance Mean Imputation: 1.3751773595216852
# Overall Mean KS Statistic BPMF: 0.0599967896983296
# Overall Mean KS Statistic Mean Imputation: 0.05700940147215666
# Overall Mean Hellinger Distance BPMF: 0.2397145458289728
# Overall Mean Hellinger Distance Mean Imputation: 0.14802475426292838
#
# Overall Mean Wasserstein Distance for PSMF Imputation: 1.5783120491982838
# Overall Mean Wasserstein Distance for Mean Imputation: 1.3751773595216852
# Overall Mean KS Statistic for PSMF Imputation: 0.04303515363518428
# Overall Mean KS Statistic for Mean Imputation: 0.05700940147215666
# Overall Mean Hellinger Distance for PSMF Imputation: 0.084795783483168
# Overall Mean Hellinger Distance for Mean Imputation: 0.14802475426292838
#
# Overall Mean Wasserstein Distance for MLESMF Imputation: 1.6641920977685893
# Overall Mean Wasserstein Distance for Mean Imputation: 1.3751773595216852
# Overall Mean KS Statistic for MLESMF Imputation: 0.05872572547974246
# Overall Mean KS Statistic for Mean Imputation: 0.05700940147215666
# Overall Mean Hellinger Distance for MLESMF Imputation: 0.17470225798756067
# Overall Mean Hellinger Distance for Mean Imputation: 0.14802475426292838
#
# Overall Mean Wasserstein Distance for PMF Imputation: 3.0342668994775623
# Overall Mean Wasserstein Distance for Mean Imputation: 1.3751773595216852
# Overall Mean KS Statistic for PMF Imputation: 0.06325745130110084
# Overall Mean KS Statistic for Mean Imputation: 0.05700940147215666
# Overall Mean Hellinger Distance for PMF Imputation: 0.33221724914707673
# Overall Mean Hellinger Distance for Mean Imputation: 0.14802475426292838
#
# Overall Mean Wasserstein Distance for rPSMF Imputation: 1.4615806621863208
# Overall Mean Wasserstein Distance for Mean Imputation: 1.3751773595216852
# Overall Mean KS Statistic for rPSMF Imputation: 0.0394832166221099
# Overall Mean KS Statistic for Mean Imputation: 0.05700940147215666
# Overall Mean Hellinger Distance for rPSMF Imputation: 0.0837293302582936
# Overall Mean Hellinger Distance for Mean Imputation: 0.14802475426292838
#
# Overall Mean Wasserstein Distance for TMF Imputation: 1.7775620885958028
# Overall Mean Wasserstein Distance for Mean Imputation: 1.3751773595216852
# Overall Mean KS Statistic for TMF Imputation: 0.060914917766279685
# Overall Mean KS Statistic for Mean Imputation: 0.05700940147215666
# Overall Mean Hellinger Distance for TMF Imputation: 0.15934921648482062
# Overall Mean Hellinger Distance for Mean Imputation: 0.14802475426292838
#
# Overall Mean Wasserstein Distance for Mean Imputation: 1.3751773595216852
# Overall Mean Wasserstein Distance for KNN Imputation: 1.3094405985191355
# Overall Mean KS Statistic for Mean Imputation: 0.05700940147215666
# Overall Mean KS Statistic for KNN Imputation: 0.042316099797066825
# Overall Mean Hellinger Distance for Mean Imputation: 0.14802475426292838
# Overall Mean Hellinger Distance for KNN Imputation: 0.08484124337129127
#
# Overall Mean Wasserstein Distance LR Imputation: 2.0681279596199347
# Overall Mean Wasserstein Distance Mean Imputation: 1.3751773595216852
# Overall Mean KS Statistic LR Imputation: 0.051837398305324085
# Overall Mean KS Statistic Mean Imputation: 0.05700940147215666
# Overall Mean Hellinger Distance LR Imputation: 0.10613580015500974
# Overall Mean Hellinger Distance Mean Imputation: 0.14802475426292838
#
# Overall Mean Wasserstein Distance for Mean Imputation: 1.3751773595216852
# Overall Mean Wasserstein Distance for Median Imputation: 1.343007701550465
# Overall Mean KS Statistic for Mean Imputation: 0.05700940147215666
# Overall Mean KS Statistic for Median Imputation: 0.05068445454496621
# Overall Mean Hellinger Distance for Mean Imputation: 0.14802475426292838
# Overall Mean Hellinger Distance for Median Imputation: 0.13579836270271398
#
# Overall Mean Wasserstein Distance for Mean Imputation: 1.3751773595216852
# Overall Mean Wasserstein Distance for NOCB & FOCB Imputation: 5.044235503157212
# Overall Mean KS Statistic for Mean Imputation: 0.05700940147215666
# Overall Mean KS Statistic for NOCB & FOCB Imputation: 0.31998286568463985
# Overall Mean Hellinger Distance for Mean Imputation: 0.14802475426292838
# Overall Mean Hellinger Distance for NOCB & FOCB Imputation: 0.4904172281920558
#
# Overall Mean Wasserstein Distance for Mean Imputation: 1.3751773595216852
# Overall Mean Wasserstein Distance for Range Imputation: 3.0772232971035525
# Overall Mean KS Statistic for Mean Imputation: 0.05700940147215666
# Overall Mean KS Statistic for Range Imputation: 0.08637207159590451
# Overall Mean Hellinger Distance for Mean Imputation: 0.14802475426292838
# Overall Mean Hellinger Distance for Range Imputation: 0.2710489511191072

# %%
twenty_percent_data = {
    "Evaluation Metric": ["Wasserstein Distance", "KS Statistic", "Hellinger Distance"],
    "Mean Imputation": [3.0217040967925137, 0.11774477793494709, 0.2540950773498757],
    "PSMF": [2.1953865022187755, 0.06102117839637443, 0.13355824312573025],
    "BPMF": [4.050994278347144, 0.10290597586845682, 0.28697185728074986],
    "MLESMF": [2.9910691943914274, 0.09996683113292858, 0.21823906667917484],
    "PMF": [4.87510423458627, 0.11473598813742208, 0.38458380985596374],
    "rPSMF": [2.07397327205102, 0.06063236538070238, 0.13378937214626682],
    "TMF": [3.4814044098207524, 0.11162190658359909, 0.20705281147688528],
    "KNN": [2.1769444678202823, 0.06317203040945885, 0.14036553073458527],
    "LR": [2.664770542949661, 0.0760891503767131, 0.1551769038661105],
    "Median Imputation": [2.949837746921215, 0.10421811640574145, 0.2358146899370257],
    "NOCB & FOCB": [5.044235503157212, 0.31998286568463985, 0.4904172281920558],
    "Range Imputation": [6.236912845626038, 0.1760444776701621, 0.3559793605972702]
}

# %% [markdown]
# 20%
# Overall Mean Wasserstein Distance for PSMF Imputation: 2.1953865022187755
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0217040967925137
# Overall Mean KS Statistic for PSMF Imputation: 0.06102117839637443
# Overall Mean KS Statistic for Mean Imputation: 0.11774477793494709
# Overall Mean Hellinger Distance for PSMF Imputation: 0.13355824312573025
# Overall Mean Hellinger Distance for Mean Imputation: 0.2540950773498757
#
# Overall Mean Wasserstein Distance BPMF: 4.050994278347144
# Overall Mean Wasserstein Distance Mean Imputation: 3.0217040967925137
# Overall Mean KS Statistic BPMF: 0.10290597586845682
# Overall Mean KS Statistic Mean Imputation: 0.11774477793494709
# Overall Mean Hellinger Distance BPMF: 0.28697185728074986
# Overall Mean Hellinger Distance Mean Imputation: 0.2540950773498757
#
# Overall Mean Wasserstein Distance for MLESMF Imputation: 2.9910691943914274
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0217040967925137
# Overall Mean KS Statistic for MLESMF Imputation: 0.09996683113292858
# Overall Mean KS Statistic for Mean Imputation: 0.11774477793494709
# Overall Mean Hellinger Distance for MLESMF Imputation: 0.21823906667917484
# Overall Mean Hellinger Distance for Mean Imputation: 0.2540950773498757
#
# Overall Mean Wasserstein Distance for PMF Imputation: 4.87510423458627
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0217040967925137
# Overall Mean KS Statistic for PMF Imputation: 0.11473598813742208
# Overall Mean KS Statistic for Mean Imputation: 0.11774477793494709
# Overall Mean Hellinger Distance for PMF Imputation: 0.38458380985596374
# Overall Mean Hellinger Distance for Mean Imputation: 0.2540950773498757
#
# Overall Mean Wasserstein Distance for rPSMF Imputation: 2.07397327205102
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0217040967925137
# Overall Mean KS Statistic for rPSMF Imputation: 0.06063236538070238
# Overall Mean KS Statistic for Mean Imputation: 0.11774477793494709
# Overall Mean Hellinger Distance for rPSMF Imputation: 0.13378937214626682
# Overall Mean Hellinger Distance for Mean Imputation: 0.2540950773498757
#
# Overall Mean Wasserstein Distance for TMF Imputation: 3.4814044098207524
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0217040967925137
# Overall Mean KS Statistic for TMF Imputation: 0.11162190658359909
# Overall Mean KS Statistic for Mean Imputation: 0.11774477793494709
# Overall Mean Hellinger Distance for TMF Imputation: 0.20705281147688528
# Overall Mean Hellinger Distance for Mean Imputation: 0.2540950773498757
#
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0217040967925137
# Overall Mean Wasserstein Distance for KNN Imputation: 2.1769444678202823
# Overall Mean KS Statistic for Mean Imputation: 0.11774477793494709
# Overall Mean KS Statistic for KNN Imputation: 0.06317203040945885
# Overall Mean Hellinger Distance for Mean Imputation: 0.2540950773498757
# Overall Mean Hellinger Distance for KNN Imputation: 0.14036553073458527
#
# Overall Mean Wasserstein Distance LR Imputation: 2.664770542949661
# Overall Mean Wasserstein Distance Mean Imputation: 3.0217040967925137
# Overall Mean KS Statistic LR Imputation: 0.0760891503767131
# Overall Mean KS Statistic Mean Imputation: 0.11774477793494709
# Overall Mean Hellinger Distance LR Imputation: 0.1551769038661105
# Overall Mean Hellinger Distance Mean Imputation: 0.2540950773498757
#
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0217040967925137
# Overall Mean Wasserstein Distance for Median Imputation: 2.949837746921215
# Overall Mean KS Statistic for Mean Imputation: 0.11774477793494709
# Overall Mean KS Statistic for Median Imputation: 0.10421811640574145
# Overall Mean Hellinger Distance for Mean Imputation: 0.2540950773498757
# Overall Mean Hellinger Distance for Median Imputation: 0.2358146899370257
#
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0217040967925137
# Overall Mean Wasserstein Distance for NOCB & FOCB Imputation: 5.044235503157212
# Overall Mean KS Statistic for Mean Imputation: 0.11774477793494709
# Overall Mean KS Statistic for NOCB & FOCB Imputation: 0.31998286568463985
# Overall Mean Hellinger Distance for Mean Imputation: 0.2540950773498757
# Overall Mean Hellinger Distance for NOCB & FOCB Imputation: 0.4904172281920558
#
# Overall Mean Wasserstein Distance for Mean Imputation: 3.0217040967925137
# Overall Mean Wasserstein Distance for Range Imputation: 6.236912845626038
# Overall Mean KS Statistic for Mean Imputation: 0.11774477793494709
# Overall Mean KS Statistic for Range Imputation: 0.1760444776701621
# Overall Mean Hellinger Distance for Mean Imputation: 0.2540950773498757
# Overall Mean Hellinger Distance for Range Imputation: 0.3559793605972702

# %%
thirty_percent_data = {
    "Evaluation Metric": ["Wasserstein Distance", "KS Statistic", "Hellinger Distance"],
    "Mean Imputation": [4.484082444735319, 0.171042548454445, 0.33040902284646484],
    "PSMF": [2.4181009085022036, 0.07233767294491752, 0.17574327854900468],
    "BPMF": [5.264322375854216, 0.1396364962221138, 0.3201543344159086],
    "MLESMF": [4.47618431836678, 0.14229791112115658, 0.25327608675979124],
    "PMF": [6.606304052365081, 0.15705712387365264, 0.43587360112825896],
    "rPSMF": [2.3003519704897326, 0.0706704967214127, 0.16894942903202173],
    "TMF": [5.179200021324014, 0.1567778474914049, 0.24185975980247953],
    "KNN": [3.09587051610232, 0.08129814232544662, 0.17930081757739066],
    "LR": [3.220593265713749, 0.09641688333526906, 0.19479266242308285],
    "Median Imputation": [4.380157574462974, 0.15146409723895554, 0.31071320712519584],
    "NOCB & FOCB": [5.044235503157212, 0.31998286568463985, 0.4904172281920558],
    "Range Imputation": [9.087278981269906, 0.2549891879034664, 0.42080865765190856]
}

# %% [markdown]
# 30%
# Overall Mean Wasserstein Distance for PSMF Imputation: 2.4181009085022036
# Overall Mean Wasserstein Distance for Mean Imputation: 4.484082444735319
# Overall Mean KS Statistic for PSMF Imputation: 0.07233767294491752
# Overall Mean KS Statistic for Mean Imputation: 0.171042548454445
# Overall Mean Hellinger Distance for PSMF Imputation: 0.17574327854900468
# Overall Mean Hellinger Distance for Mean Imputation: 0.33040902284646484
#
# Overall Mean Wasserstein Distance BPMF: 5.264322375854216
# Overall Mean Wasserstein Distance Mean Imputation: 4.484082444735319
# Overall Mean KS Statistic BPMF: 0.1396364962221138
# Overall Mean KS Statistic Mean Imputation: 0.171042548454445
# Overall Mean Hellinger Distance BPMF: 0.3201543344159086
# Overall Mean Hellinger Distance Mean Imputation: 0.33040902284646484
#
# Overall Mean Wasserstein Distance for MLESMF Imputation: 4.47618431836678
# Overall Mean Wasserstein Distance for Mean Imputation: 4.484082444735319
# Overall Mean KS Statistic for MLESMF Imputation: 0.14229791112115658
# Overall Mean KS Statistic for Mean Imputation: 0.171042548454445
# Overall Mean Hellinger Distance for MLESMF Imputation: 0.25327608675979124
# Overall Mean Hellinger Distance for Mean Imputation: 0.33040902284646484
#
# Overall Mean Wasserstein Distance for PMF Imputation: 6.606304052365081
# Overall Mean Wasserstein Distance for Mean Imputation: 4.484082444735319
# Overall Mean KS Statistic for PMF Imputation: 0.15705712387365264
# Overall Mean KS Statistic for Mean Imputation: 0.171042548454445
# Overall Mean Hellinger Distance for PMF Imputation: 0.43587360112825896
# Overall Mean Hellinger Distance for Mean Imputation: 0.33040902284646484
#
# Overall Mean Wasserstein Distance for rPSMF Imputation: 2.3003519704897326
# Overall Mean Wasserstein Distance for Mean Imputation: 4.484082444735319
# Overall Mean KS Statistic for rPSMF Imputation: 0.0706704967214127
# Overall Mean KS Statistic for Mean Imputation: 0.171042548454445
# Overall Mean Hellinger Distance for rPSMF Imputation: 0.16894942903202173
# Overall Mean Hellinger Distance for Mean Imputation: 0.33040902284646484
#
# Overall Mean Wasserstein Distance for TMF Imputation: 5.179200021324014
# Overall Mean Wasserstein Distance for Mean Imputation: 4.484082444735319
# Overall Mean KS Statistic for TMF Imputation: 0.1567778474914049
# Overall Mean KS Statistic for Mean Imputation: 0.171042548454445
# Overall Mean Hellinger Distance for TMF Imputation: 0.24185975980247953
# Overall Mean Hellinger Distance for Mean Imputation: 0.33040902284646484
#
# Overall Mean Wasserstein Distance for Mean Imputation: 4.484082444735319
# Overall Mean Wasserstein Distance for KNN Imputation: 3.09587051610232
# Overall Mean KS Statistic for Mean Imputation: 0.171042548454445
# Overall Mean KS Statistic for KNN Imputation: 0.08129814232544662
# Overall Mean Hellinger Distance for Mean Imputation: 0.33040902284646484
# Overall Mean Hellinger Distance for KNN Imputation: 0.17930081757739066
#
# Overall Mean Wasserstein Distance LR Imputation: 3.220593265713749
# Overall Mean Wasserstein Distance Mean Imputation: 4.484082444735319
# Overall Mean KS Statistic LR Imputation: 0.09641688333526906
# Overall Mean KS Statistic Mean Imputation: 0.171042548454445
# Overall Mean Hellinger Distance LR Imputation: 0.19479266242308285
# Overall Mean Hellinger Distance Mean Imputation: 0.33040902284646484
#
# Overall Mean Wasserstein Distance for Mean Imputation: 4.484082444735319
# Overall Mean Wasserstein Distance for Median Imputation: 4.380157574462974
# Overall Mean KS Statistic for Mean Imputation: 0.171042548454445
# Overall Mean KS Statistic for Median Imputation: 0.15146409723895554
# Overall Mean Hellinger Distance for Mean Imputation: 0.33040902284646484
# Overall Mean Hellinger Distance for Median Imputation: 0.31071320712519584
#
# Overall Mean Wasserstein Distance for Mean Imputation: 4.484082444735319
# Overall Mean Wasserstein Distance for NOCB & FOCB Imputation: 5.044235503157212
# Overall Mean KS Statistic for Mean Imputation: 0.171042548454445
# Overall Mean KS Statistic for NOCB & FOCB Imputation: 0.31998286568463985
# Overall Mean Hellinger Distance for Mean Imputation: 0.33040902284646484
# Overall Mean Hellinger Distance for NOCB & FOCB Imputation: 0.4904172281920558
#
# Overall Mean Wasserstein Distance for Mean Imputation: 4.484082444735319
# Overall Mean Wasserstein Distance for Range Imputation: 9.087278981269906
# Overall Mean KS Statistic for Mean Imputation: 0.171042548454445
# Overall Mean KS Statistic for Range Imputation: 0.2549891879034664
# Overall Mean Hellinger Distance for Mean Imputation: 0.33040902284646484
# Overall Mean Hellinger Distance for Range Imputation: 0.42080865765190856

# %%
forty_percent_data = {
    "Evaluation Metric": ["Wasserstein Distance", "KS Statistic", "Hellinger Distance"],
    "Mean Imputation": [6.168276269677526, 0.23077178311444096, 0.40941350626966405],
    "PSMF": [3.1599696552446894, 0.09020173522050283, 0.2209584370438053],
    "BPMF": [6.577210120856479, 0.17952657431691588, 0.35145842222569473],
    "MLESMF": [5.931883790577378, 0.18613504676919496, 0.30135933550453337],
    "PMF": [8.180116409824256, 0.19771384682697354, 0.4772143538737827],
    "rPSMF": [2.949146797207214, 0.0869629716042152, 0.20638914058951313],
    "TMF": [6.8690596595964575, 0.2083365851775439, 0.28572287036818234],
    "KNN": [4.1436255055829925, 0.10052387186441086, 0.21661175230804333],
    "LR": [3.7990862160665886, 0.1174910373649221, 0.2353609427062244],
    "Median Imputation": [6.024844248199749, 0.20364331147608247, 0.3894309693895483],
    "NOCB & FOCB": [5.044235503157212, 0.31998286568463985, 0.4904172281920558],
    "Range Imputation": [12.18443433899082, 0.34333507693180776, 0.488330513947755]
}

# %% [markdown]
# 40%
# Overall Mean Wasserstein Distance for PSMF Imputation: 3.1599696552446894
# Overall Mean Wasserstein Distance for Mean Imputation: 6.168276269677526
# Overall Mean KS Statistic for PSMF Imputation: 0.09020173522050283
# Overall Mean KS Statistic for Mean Imputation: 0.23077178311444096
# Overall Mean Hellinger Distance for PSMF Imputation: 0.2209584370438053
# Overall Mean Hellinger Distance for Mean Imputation: 0.40941350626966405
#
# Overall Mean Wasserstein Distance BPMF: 6.577210120856479
# Overall Mean Wasserstein Distance Mean Imputation: 6.168276269677526
# Overall Mean KS Statistic BPMF: 0.17952657431691588
# Overall Mean KS Statistic Mean Imputation: 0.23077178311444096
# Overall Mean Hellinger Distance BPMF: 0.35145842222569473
# Overall Mean Hellinger Distance Mean Imputation: 0.40941350626966405
#
# Overall Mean Wasserstein Distance for MLESMF Imputation: 5.931883790577378
# Overall Mean Wasserstein Distance for Mean Imputation: 6.168276269677526
# Overall Mean KS Statistic for MLESMF Imputation: 0.18613504676919496
# Overall Mean KS Statistic for Mean Imputation: 0.23077178311444096
# Overall Mean Hellinger Distance for MLESMF Imputation: 0.30135933550453337
# Overall Mean Hellinger Distance for Mean Imputation: 0.40941350626966405
#
# Overall Mean Wasserstein Distance for PMF Imputation: 8.180116409824256
# Overall Mean Wasserstein Distance for Mean Imputation: 6.168276269677526
# Overall Mean KS Statistic for PMF Imputation: 0.19771384682697354
# Overall Mean KS Statistic for Mean Imputation: 0.23077178311444096
# Overall Mean Hellinger Distance for PMF Imputation: 0.4772143538737827
# Overall Mean Hellinger Distance for Mean Imputation: 0.40941350626966405
#
# Overall Mean Wasserstein Distance for rPSMF Imputation: 2.949146797207214
# Overall Mean Wasserstein Distance for Mean Imputation: 6.168276269677526
# Overall Mean KS Statistic for rPSMF Imputation: 0.0869629716042152
# Overall Mean KS Statistic for Mean Imputation: 0.23077178311444096
# Overall Mean Hellinger Distance for rPSMF Imputation: 0.20638914058951313
# Overall Mean Hellinger Distance for Mean Imputation: 0.40941350626966405
#
# Overall Mean Wasserstein Distance for TMF Imputation: 6.8690596595964575
# Overall Mean Wasserstein Distance for Mean Imputation: 6.168276269677526
# Overall Mean KS Statistic for TMF Imputation: 0.2083365851775439
# Overall Mean KS Statistic for Mean Imputation: 0.23077178311444096
# Overall Mean Hellinger Distance for TMF Imputation: 0.28572287036818234
# Overall Mean Hellinger Distance for Mean Imputation: 0.40941350626966405
#
# Overall Mean Wasserstein Distance for Mean Imputation: 6.168276269677526
# Overall Mean Wasserstein Distance for KNN Imputation: 4.1436255055829925
# Overall Mean KS Statistic for Mean Imputation: 0.23077178311444096
# Overall Mean KS Statistic for KNN Imputation: 0.10052387186441086
# Overall Mean Hellinger Distance for Mean Imputation: 0.40941350626966405
# Overall Mean Hellinger Distance for KNN Imputation: 0.21661175230804333
#
# Overall Mean Wasserstein Distance LR Imputation: 3.7990862160665886
# Overall Mean Wasserstein Distance Mean Imputation: 6.168276269677526
# Overall Mean KS Statistic LR Imputation: 0.1174910373649221
# Overall Mean KS Statistic Mean Imputation: 0.23077178311444096
# Overall Mean Hellinger Distance LR Imputation: 0.2353609427062244
# Overall Mean Hellinger Distance Mean Imputation: 0.40941350626966405
#
# Overall Mean Wasserstein Distance for Mean Imputation: 6.168276269677526
# Overall Mean Wasserstein Distance for Median Imputation: 6.024844248199749
# Overall Mean KS Statistic for Mean Imputation: 0.23077178311444096
# Overall Mean KS Statistic for Median Imputation: 0.20364331147608247
# Overall Mean Hellinger Distance for Mean Imputation: 0.40941350626966405
# Overall Mean Hellinger Distance for Median Imputation: 0.3894309693895483
#
# Overall Mean Wasserstein Distance for Mean Imputation: 6.168276269677526
# Overall Mean Wasserstein Distance for NOCB & FOCB Imputation: 5.044235503157212
# Overall Mean KS Statistic for Mean Imputation: 0.23077178311444096
# Overall Mean KS Statistic for NOCB & FOCB Imputation: 0.31998286568463985
# Overall Mean Hellinger Distance for Mean Imputation: 0.40941350626966405
# Overall Mean Hellinger Distance for NOCB & FOCB Imputation: 0.4904172281920558
#
# Overall Mean Wasserstein Distance for Mean Imputation: 6.168276269677526
# Overall Mean Wasserstein Distance for Range Imputation: 12.18443433899082
# Overall Mean KS Statistic for Mean Imputation: 0.23077178311444096
# Overall Mean KS Statistic for Range Imputation: 0.34333507693180776
# Overall Mean Hellinger Distance for Mean Imputation: 0.40941350626966405
# Overall Mean Hellinger Distance for Range Imputation: 0.488330513947755

# %%
fifty_percent_data = {
    "Evaluation Metric": ["Wasserstein Distance", "KS Statistic", "Hellinger Distance"],
    "Mean Imputation": [7.54628136394338, 0.2872127307331157, 0.48455400856043307],
    "PSMF": [3.9456339804201486, 0.10979866788076342, 0.26719512152469727],
    "BPMF": [7.633255658264336, 0.21805406251356513, 0.3977541651311435],
    "MLESMF": [7.28210435183422, 0.22592446921364367, 0.33952437518118983],
    "PMF": [9.267516753951378, 0.23545926001364412, 0.4765984114701032],
    "rPSMF": [3.6275454565586913, 0.10392297333874553, 0.25453918819391497],
    "TMF": [8.594130795174923, 0.25675060984229653, 0.3288738132167254],
    "KNN": [5.224453839941028, 0.12391754166398276, 0.2611825027301543],
    "LR": [4.553859613409442, 0.13909255993867486, 0.27480433722266834],
    "Median Imputation": [7.366243052379856, 0.2532556865046649, 0.4578337548129618],
    "NOCB & FOCB": [5.044235503157212, 0.31998286568463985, 0.4904172281920558],
    "Range Imputation": [15.163537282664812, 0.4279883645311837, 0.5496273782846006]
}

# %% [markdown]
# 50%
# Overall Mean Wasserstein Distance for PSMF Imputation: 3.9456339804201486
# Overall Mean Wasserstein Distance for Mean Imputation: 7.54628136394338
# Overall Mean KS Statistic for PSMF Imputation: 0.10979866788076342
# Overall Mean KS Statistic for Mean Imputation: 0.2872127307331157
# Overall Mean Hellinger Distance for PSMF Imputation: 0.26719512152469727
# Overall Mean Hellinger Distance for Mean Imputation: 0.48455400856043307
#
# Overall Mean Wasserstein Distance BPMF: 7.633255658264336
# Overall Mean Wasserstein Distance Mean Imputation: 7.54628136394338
# Overall Mean KS Statistic BPMF: 0.21805406251356513
# Overall Mean KS Statistic Mean Imputation: 0.2872127307331157
# Overall Mean Hellinger Distance BPMF: 0.3977541651311435
# Overall Mean Hellinger Distance Mean Imputation: 0.48455400856043307
#
# Overall Mean Wasserstein Distance for MLESMF Imputation: 7.28210435183422
# Overall Mean Wasserstein Distance for Mean Imputation: 7.54628136394338
# Overall Mean KS Statistic for MLESMF Imputation: 0.22592446921364367
# Overall Mean KS Statistic for Mean Imputation: 0.2872127307331157
# Overall Mean Hellinger Distance for MLESMF Imputation: 0.33952437518118983
# Overall Mean Hellinger Distance for Mean Imputation: 0.48455400856043307
#
# Overall Mean Wasserstein Distance for PMF Imputation: 9.267516753951378
# Overall Mean Wasserstein Distance for Mean Imputation: 7.54628136394338
# Overall Mean KS Statistic for PMF Imputation: 0.23545926001364412
# Overall Mean KS Statistic for Mean Imputation: 0.2872127307331157
# Overall Mean Hellinger Distance for PMF Imputation: 0.4765984114701032
# Overall Mean Hellinger Distance for Mean Imputation: 0.48455400856043307
#
# Overall Mean Wasserstein Distance for rPSMF Imputation: 3.6275454565586913
# Overall Mean Wasserstein Distance for Mean Imputation: 7.54628136394338
# Overall Mean KS Statistic for rPSMF Imputation: 0.10392297333874553
# Overall Mean KS Statistic for Mean Imputation: 0.2872127307331157
# Overall Mean Hellinger Distance for rPSMF Imputation: 0.25453918819391497
# Overall Mean Hellinger Distance for Mean Imputation: 0.48455400856043307
#
# Overall Mean Wasserstein Distance for TMF Imputation: 8.594130795174923
# Overall Mean Wasserstein Distance for Mean Imputation: 7.54628136394338
# Overall Mean KS Statistic for TMF Imputation: 0.25675060984229653
# Overall Mean KS Statistic for Mean Imputation: 0.2872127307331157
# Overall Mean Hellinger Distance for TMF Imputation: 0.3288738132167254
# Overall Mean Hellinger Distance for Mean Imputation: 0.48455400856043307
#
# Overall Mean Wasserstein Distance for Mean Imputation: 7.54628136394338
# Overall Mean Wasserstein Distance for KNN Imputation: 5.224453839941028
# Overall Mean KS Statistic for Mean Imputation: 0.2872127307331157
# Overall Mean KS Statistic for KNN Imputation: 0.12391754166398276
# Overall Mean Hellinger Distance for Mean Imputation: 0.48455400856043307
# Overall Mean Hellinger Distance for KNN Imputation: 0.2611825027301543
#
# Overall Mean Wasserstein Distance LR Imputation: 4.553859613409442
# Overall Mean Wasserstein Distance Mean Imputation: 7.54628136394338
# Overall Mean KS Statistic LR Imputation: 0.13909255993867486
# Overall Mean KS Statistic Mean Imputation: 0.2872127307331157
# Overall Mean Hellinger Distance LR Imputation: 0.27480433722266834
# Overall Mean Hellinger Distance Mean Imputation: 0.48455400856043307
#
# Overall Mean Wasserstein Distance for Mean Imputation: 7.54628136394338
# Overall Mean Wasserstein Distance for Median Imputation: 7.366243052379856
# Overall Mean KS Statistic for Mean Imputation: 0.2872127307331157
# Overall Mean KS Statistic for Median Imputation: 0.2532556865046649
# Overall Mean Hellinger Distance for Mean Imputation: 0.48455400856043307
# Overall Mean Hellinger Distance for Median Imputation: 0.4578337548129618
#
# Overall Mean Wasserstein Distance for Mean Imputation: 7.54628136394338
# Overall Mean Wasserstein Distance for NOCB & FOCB Imputation: 5.044235503157212
# Overall Mean KS Statistic for Mean Imputation: 0.2872127307331157
# Overall Mean KS Statistic for NOCB & FOCB Imputation: 0.31998286568463985
# Overall Mean Hellinger Distance for Mean Imputation: 0.48455400856043307
# Overall Mean Hellinger Distance for NOCB & FOCB Imputation: 0.4904172281920558
#
# Overall Mean Wasserstein Distance for Mean Imputation: 7.54628136394338
# Overall Mean Wasserstein Distance for Range Imputation: 15.163537282664812
# Overall Mean KS Statistic for Mean Imputation: 0.2872127307331157
# Overall Mean KS Statistic for Range Imputation: 0.4279883645311837
# Overall Mean Hellinger Distance for Mean Imputation: 0.48455400856043307
# Overall Mean Hellinger Distance for Range Imputation: 0.5496273782846006
